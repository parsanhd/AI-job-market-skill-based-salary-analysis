# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Test').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Hersheyyyyy:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.parquet('cleaned_postings.parquet')
df_pyspark=spark.read.option('header','true').parquet('cleaned_postings.parquet',inferSchema=True)

# %%
type(df_pyspark)
df_pyspark.printSchema()
# Out:
# root
#  |-- job_id: long (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- skills_desc: string (nullable = true)
#  |-- normalized_salary: double (nullable = true)
#  |-- formatted_experience_level: string (nullable = true)
#  |-- formatted_work_type: string (nullable = true)
#  |-- remote_allowed: boolean (nullable = true)
#  |-- posting_domain: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- listed_time: double (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- extracted_skills: string (nullable = true)

# %%
from pyspark.sql import functions as F
df_rows = df_pyspark.withColumn("extracted_individual_skill", F.explode(F.split(F.col("extracted_skills"), "\|")))
df_rows.show(50)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\|'
# <>:2: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\harsh\AppData\Local\Temp\ipykernel_20624\2931386557.py:2: SyntaxWarning: invalid escape sequence '\|'
#   df_rows = df_pyspark.withColumn("extracted_individual_skill", F.explode(F.split(F.col("extracted_skills"), "\|")))
# +---------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------+--------------------+-----------+--------+--------------------+--------------------------+
# |   job_id|        company_name|               title|         description|         skills_desc|normalized_salary|formatted_experience_level|formatted_work_type|remote_allowed|posting_domain|            location|listed_time|zip_code|    extracted_skills|extracted_individual_skill|
# +---------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------+--------------------+-----------+--------+--------------------+--------------------------+
# |   921716|Corcoran Sawyer S...|Marketing Coordin...|Job descriptionA ...|Requirements: \n\...|          38480.0|                      NULL|          Full-time|         false|          NULL|       Princeton, NJ|  1.7134E12|  8540.0|                    |                          |
# |  1829192|             Unknown|Mental Health The...|At Aspen Therapy ...|                    |          83200.0|                      NULL|          Full-time|         false|          NULL|    Fort Collins, CO| 1.71286E12|  8540.0|                    |                          |
# | 10998357|The National Exem...|Assitant Restaura...|The National Exem...|We are currently ...|          55000.0|                      NULL|          Full-time|         false|          NULL|      Cincinnati, OH| 1.71328E12|  8540.0|                    |                          |
# | 23221523|Abrams Fensterman...|Senior Elder Law ...|Senior Associate ...|This position req...|         157500.0|                      NULL|          Full-time|         false|          NULL|   New Hyde Park, NY|  1.7129E12|  8540.0|                    |                          |
# | 35982263|             Unknown|  Service Technician|Looking for HVAC ...|                    |          70000.0|                      NULL|          Full-time|         false|          NULL|      Burlington, IA| 1.71345E12|  8540.0|                    |                          |
# | 91700727|Downtown Raleigh ...|Economic Developm...|Job summary:The E...|                    |          35360.0|                      NULL|         Internship|         false|          NULL|         Raleigh, NC| 1.71346E12|  8540.0|                    |                          |
# |103254301|          Raw Cereal|            Producer|Company Descripti...|                    |         180000.0|                      NULL|           Contract|          true|          NULL|       United States| 1.71286E12|  8540.0|                    |                          |
# |112576855|             Unknown|   Building Engineer|Summary: Due to t...|                    |         105000.0|                      NULL|          Full-time|         false|          NULL|   San Francisco, CA| 1.71244E12|  8540.0|                    |                          |
# |  1218575| Children's Nebraska|Respiratory Thera...|At Children’s, th...|• Requires the ab...|              0.0|                      NULL|          Full-time|         false|          NULL|           Omaha, NE| 1.71235E12|  8540.0|                    |                          |
# |  2264355|     Bay West Church|      Worship Leader|It is an exciting...|Knowledge, Skills...|           4200.0|                      NULL|          Part-time|         false|          NULL|        Palm Bay, FL| 1.71246E12|  8540.0|                    |                          |
# |  9615617|    Glastender, Inc.|Inside Customer S...|Glastender Inc. i...|The Production Su...|              0.0|                      NULL|          Full-time|         false|          NULL|         Saginaw, MI| 1.71321E12|  8540.0|                    |                          |
# | 11009123|   PGAV Destinations|   Project Architect|PGAV Destinations...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|        St Louis, MO| 1.71286E12|  8540.0|                    |                          |
# | 56482768|             Unknown|Appalachian Highl...|FULL JOB DESCRIPT...|Skills/Qualificat...|              0.0|                      NULL|          Full-time|         false|          NULL|       Kingsport, TN| 1.71287E12|  8540.0|               excel|                     excel|
# | 56924323|             Unknown| Structural Engineer|Universal Structu...|Job Overview: Man...|              0.0|                      NULL|          Full-time|         false|          NULL|       San Mateo, CA| 1.71246E12|  8540.0|               excel|                     excel|
# | 69333422|     Staffing Theory|Senior Product Ma...|A leading pharmac...|                    |              0.0|                      NULL|          Full-time|          true|          NULL|       United States| 1.71354E12|  8540.0|                    |                          |
# | 83789755|         OsteoStrong|Osteogenic Loadin...|Company Descripti...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|       Anchorage, AK| 1.71347E12|  8540.0|                  go|                        go|
# | 95428182|CLEVELAND KIDS BO...|Administrative Co...|Job Title: Admini...|                    |          52000.0|                      NULL|          Full-time|         false|          NULL|       Cleveland, OH| 1.71286E12|  8540.0|                    |                          |
# |103860943|             Unknown|Customer Service ...|Sentinel Limousin...|                    |          38480.0|                      NULL|          Part-time|         false|          NULL|      Providence, RI| 1.71353E12|  8540.0|                    |                          |
# |111513530|United Methodists...|Content Writer, C...|Application openi...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|Greater Philadelphia| 1.71346E12|  8540.0|                    |                          |
# |115639136|   Shannon Waltchack|          Controller|WORK @ SWShannon ...|Strong interperso...|              0.0|                      NULL|          Full-time|         false|          NULL|      Birmingham, AL| 1.71321E12|  8540.0|               excel|                     excel|
# |117675818|Premier Family Cl...| Physician Assistant|We are seeking a ...|                    |              0.0|                      NULL|           Contract|         false|          NULL|         Atlanta, GA| 1.71267E12|  8540.0|                    |                          |
# |121605673|             Unknown|Licensed Acupunct...|Why Work Here?“We...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|          Maumee, OH| 1.71347E12|  8540.0|                    |                          |
# |133130219|             Unknown|   Software Engineer|Education Bachelo...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|Los Angeles Metro...| 1.71354E12|  8540.0|                    |                          |
# |134286190|             Unknown|Sheet Metal Fabri...|Sheet metal fabri...|Data Entry Filing...|              0.0|                      NULL|          Full-time|         false|          NULL|   Mineral Wells, TX| 1.71346E12|  8540.0|               excel|                     excel|
# |136743465|             Unknown|Personal Injury A...|About Us: We are ...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|          Stuart, FL| 1.71347E12|  8540.0|                  go|                        go|
# |141969940|          PRM-TAIWAN|NPE 2024 Exhibiti...|NPE 2024 Exhibiti...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|         Orlando, FL| 1.71265E12|  8540.0|                    |                          |
# |175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                       css|
# |175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                      html|
# |175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                javascript|
# |175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                     mysql|
# |175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                       php|
# |196406165|             Unknown|    Loan Coordinator|Morlen Capital Ad...|                    |              0.0|                      NULL|           Contract|          true|          NULL|New Jersey, Unite...| 1.71353E12|  8540.0|               excel|                     excel|
# |227832999|             Unknown|     General Laborer|Looking for a Gen...|                    |          43680.0|                      NULL|          Full-time|         false|          NULL|            Erie, PA| 1.71328E12|  8540.0|               excel|                     excel|
# |228003844|Harlingen Country...|     Swim Instructor|HCC is looking to...|                    |              0.0|                      NULL|           Contract|         false|          NULL|       Harlingen, TX| 1.71339E12|  8540.0|                    |                          |
# |229924287|REquipment Durabl...|Administrative As...|The Administrativ...|                    |          47840.0|                      NULL|          Part-time|         false|          NULL|          Woburn, MA| 1.71355E12|  8540.0|                    |                          |
# |231010577|Pierce Refrigeration|Service / Constru...|Company Descripti...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|West Bridgewater, MA| 1.71246E12|  8540.0|                    |                          |
# |243731357|Fidelity National...|     Legal Secretary|Description Legal...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|         Phoenix, AZ| 1.71244E12|  8540.0|                    |                          |
# |258868844|                ABME|         Salesperson|ABME, a leader in...|                    |              0.0|                      NULL|          Full-time|          true|          NULL|       United States| 1.71347E12|  8540.0|                    |                          |
# |263583866|      Atrium Centers|    Registered Nurse|We currently need...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|        Grayling, MI| 1.71347E12|  8540.0|                    |                          |
# |266566927|  Revesco Properties|Marketing & Offic...|About Revesco Pro...|                    |          65000.0|                      NULL|          Full-time|         false|          NULL|          Denver, CO| 1.71346E12|  8540.0|               excel|                     excel|
# |266825034|  Recruitment Design|Software Support ...|Are you driven by...|                    |          62500.0|                      NULL|          Full-time|         false|          NULL|          McLean, VA| 1.71286E12|  8540.0|      javascript|php|                javascript|
# |266825034|  Recruitment Design|Software Support ...|Are you driven by...|                    |          62500.0|                      NULL|          Full-time|         false|          NULL|          McLean, VA| 1.71286E12|  8540.0|      javascript|php|                       php|
# |280496925|Washington State ...|Coordinator for M...|The Coordinator s...|                    |          53268.0|                      NULL|          Full-time|         false|          NULL|         Pullman, WA| 1.71346E12|  8540.0|                    |                          |
# |345332937|Headquarters Barb...|              Barber|Part time Barber,...|                    |              0.0|                      NULL|          Part-time|         false|          NULL|         Grafton, WI|  1.7134E12|  8540.0|                    |                          |
# |358267047| ADEPT HRM Solutions|Production Planne...|Job Summary: We a...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|         Concord, NC| 1.71235E12|  8540.0|                    |                          |
# |368586246|       STL Fertility|        Embryologist|Job duties:To rec...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|        St Louis, MO| 1.71345E12|  8540.0|               excel|                     excel|
# |445337908| Food Bank of Alaska|Chief Operating O...|The Chief Operati...|                    |         100000.0|                      NULL|          Full-time|         false|          NULL|       Anchorage, AK| 1.71355E12|  8540.0|                    |                          |
# |606178500|Jung & Vassar PC ...|  Associate Attorney|Big Island firm s...|                    |         120000.0|                      NULL|          Full-time|         false|          NULL|     Kailua-Kona, HI| 1.71244E12|  8540.0|                    |                          |
# |634823509|             Unknown|     HVAC Technician|Service and insta...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|        Brooklyn, NY| 1.71349E12|  8540.0|                    |                          |
# |658723396|Orlando Credit Union|External Mortgage...|Full job descript...|                    |              0.0|                      NULL|          Full-time|         false|          NULL|         Orlando, FL| 1.71349E12|  8540.0|                    |                          |
# +---------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------+--------------------+-----------+--------+--------------------+--------------------------+
# only showing top 50 rows

# %%
(
    df_rows
    .filter(F.col("extracted_individual_skill").isNotNull())
    .filter(F.trim(F.col("extracted_individual_skill")) != "")
    .groupBy("extracted_individual_skill")
    .count()
    .orderBy(F.desc("count"))
    .show(50, truncate=False)
)
# Out:
# +--------------------------+-----+
# |extracted_individual_skill|count|
# +--------------------------+-----+
# |excel                     |17851|
# |go                        |8762 |
# |agile                     |5932 |
# |c                         |5406 |
# |sql                       |5039 |
# |python                    |4536 |
# |aws                       |3034 |
# |forecasting               |2956 |
# |azure                     |2825 |
# |rest                      |2712 |
# |java                      |2631 |
# |oracle                    |2301 |
# |statistics                |1943 |
# |javascript                |1904 |
# |express                   |1791 |
# |machine learning          |1704 |
# |scrum                     |1527 |
# |jira                      |1480 |
# |r                         |1479 |
# |react                     |1358 |
# |ci/cd                     |1325 |
# |html                      |1237 |
# |c++                       |1225 |
# |tableau                   |1214 |
# |spring                    |1143 |
# |git                       |1134 |
# |kubernetes                |1091 |
# |c#                        |1074 |
# |docker                    |1032 |
# |artificial intelligence   |1030 |
# |power bi                  |988  |
# |gcp                       |928  |
# |css                       |920  |
# |sql server                |897  |
# |etl                       |872  |
# |spark                     |837  |
# |.net                      |764  |
# |jenkins                   |728  |
# |powershell                |678  |
# |angular                   |660  |
# |data modeling             |646  |
# |shell                     |639  |
# |terraform                 |635  |
# |confluence                |547  |
# |kafka                     |531  |
# |google cloud              |522  |
# |snowflake                 |513  |
# |typescript                |510  |
# |ansible                   |506  |
# |github                    |504  |
# +--------------------------+-----+
# only showing top 50 rows

# %%
skill_map = {
    "node.js": "nodejs",
    "ci / cd": "ci/cd",
    "amazon web services": "aws",
    "natural language processing": "nlp",
    "golang": "go",
    "postgres": "postgresql",
    "c #": "c#",
    "apache spark": "spark",
    "ab testing": "a/b testing"
    #add more if needed
}
mapping_expr = F.create_map(
    *[F.lit(x) for pair in skill_map.items() for x in pair]
)

df_norm = df_rows.withColumn(
    "skill",
    F.coalesce(mapping_expr[F.col("extracted_individual_skill")], F.col("extracted_individual_skill"))
)

# %%
(
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .dropDuplicates(["job_id", "skill"])
    .groupBy("skill")
    .count()
    .orderBy(F.desc("count"))
    .show(50, truncate=False)
)
# Out:
# +-----------------------+-----+
# |skill                  |count|
# +-----------------------+-----+
# |excel                  |17851|
# |go                     |8893 |
# |agile                  |5932 |
# |c                      |5406 |
# |sql                    |5039 |
# |python                 |4536 |
# |aws                    |3118 |
# |forecasting            |2956 |
# |azure                  |2825 |
# |rest                   |2712 |
# |java                   |2631 |
# |oracle                 |2301 |
# |statistics             |1943 |
# |javascript             |1904 |
# |express                |1791 |
# |machine learning       |1704 |
# |scrum                  |1527 |
# |jira                   |1480 |
# |r                      |1479 |
# |react                  |1358 |
# |ci/cd                  |1339 |
# |html                   |1237 |
# |c++                    |1225 |
# |tableau                |1214 |
# |spring                 |1143 |
# |git                    |1134 |
# |kubernetes             |1091 |
# |c#                     |1077 |
# |docker                 |1032 |
# |artificial intelligence|1030 |
# |power bi               |988  |
# |gcp                    |928  |
# |css                    |920  |
# |sql server             |897  |
# |etl                    |872  |
# |spark                  |837  |
# |.net                   |764  |
# |jenkins                |728  |
# |powershell             |678  |
# |angular                |660  |
# |data modeling          |646  |
# |shell                  |639  |
# |terraform              |635  |
# |confluence             |547  |
# |kafka                  |531  |
# |postgresql             |523  |
# |google cloud           |522  |
# |snowflake              |513  |
# |typescript             |510  |
# |ansible                |506  |
# +-----------------------+-----+
# only showing top 50 rows

# %%
skills_by_level = (
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .fillna({"formatted_experience_level": "Unknown"})
    .groupBy("formatted_experience_level", "skill")
    .agg(F.countDistinct("job_id").alias("job_count"))
    .orderBy("formatted_experience_level", F.desc("job_count"))
)

skills_by_level.show(50, truncate=False)
# Out:
# +--------------------------+-----------------------+---------+
# |formatted_experience_level|skill                  |job_count|
# +--------------------------+-----------------------+---------+
# |Associate                 |excel                  |1961     |
# |Associate                 |go                     |614      |
# |Associate                 |agile                  |429      |
# |Associate                 |sql                    |351      |
# |Associate                 |c                      |303      |
# |Associate                 |python                 |267      |
# |Associate                 |forecasting            |244      |
# |Associate                 |statistics             |181      |
# |Associate                 |oracle                 |158      |
# |Associate                 |azure                  |148      |
# |Associate                 |aws                    |127      |
# |Associate                 |r                      |124      |
# |Associate                 |jira                   |122      |
# |Associate                 |rest                   |121      |
# |Associate                 |java                   |117      |
# |Associate                 |tableau                |103      |
# |Associate                 |spring                 |98       |
# |Associate                 |machine learning       |95       |
# |Associate                 |express                |92       |
# |Associate                 |react                  |81       |
# |Associate                 |power bi               |78       |
# |Associate                 |javascript             |73       |
# |Associate                 |scrum                  |70       |
# |Associate                 |c++                    |68       |
# |Associate                 |html                   |64       |
# |Associate                 |css                    |61       |
# |Associate                 |powershell             |54       |
# |Associate                 |spark                  |54       |
# |Associate                 |git                    |50       |
# |Associate                 |gcp                    |49       |
# |Associate                 |etl                    |49       |
# |Associate                 |sql server             |47       |
# |Associate                 |artificial intelligence|46       |
# |Associate                 |ci/cd                  |42       |
# |Associate                 |c#                     |40       |
# |Associate                 |shell                  |39       |
# |Associate                 |swift                  |38       |
# |Associate                 |kubernetes             |38       |
# |Associate                 |docker                 |36       |
# |Associate                 |confluence             |33       |
# |Associate                 |postgresql             |28       |
# |Associate                 |terraform              |28       |
# |Associate                 |github                 |28       |
# |Associate                 |typescript             |28       |
# |Associate                 |snowflake              |26       |
# |Associate                 |kafka                  |26       |
# |Associate                 |data modeling          |26       |
# |Associate                 |.net                   |25       |
# |Associate                 |encryption             |25       |
# |Associate                 |angular                |24       |
# +--------------------------+-----------------------+---------+
# only showing top 50 rows

# %%
from pyspark.sql.functions import expr
job_skills = (
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .groupBy("job_id")
    .agg(F.collect_set("skill").alias("skills"))
)
# job_skills.show(50, truncate=False)
skill_pairs = (
    job_skills
    .withColumn(
        "skill_pairs",
        expr("""
            transform(
                filter(
                    sequence(0, size(skills) - 1),
                    i -> i < size(skills) - 1
                ),
                i -> transform(
                    sequence(i + 1, size(skills) - 1),
                    j -> struct(
                        skills[i] as skill_a,
                        skills[j] as skill_b
                    )
                )
            )
        """)
    )
    .select("job_id", F.explode("skill_pairs").alias("pairs"))
    .select("job_id", F.explode("pairs").alias("pair"))
    .select("job_id","pair.skill_a", "pair.skill_b")
)
skill_bundle_counts = (
    skill_pairs
    .groupBy("skill_a", "skill_b")
    .agg(F.countDistinct("job_id").alias("job_count"))
    .orderBy(F.desc("job_count"))
)
skill_bundle_counts.show(50, truncate=False)
# Out:
# +----------+-------------------------------------------------------------------------------------------------------------------------+
# |job_id    |skills                                                                                                                   |
# +----------+-------------------------------------------------------------------------------------------------------------------------+
# |83789755  |[go]                                                                                                                     |
# |115639136 |[excel]                                                                                                                  |
# |134286190 |[excel]                                                                                                                  |
# |136743465 |[go]                                                                                                                     |
# |175485704 |[mysql, javascript, html, css, php]                                                                                      |
# |196406165 |[excel]                                                                                                                  |
# |266825034 |[javascript, php]                                                                                                        |
# |1183148438|[athena]                                                                                                                 |
# |1826257634|[excel, go]                                                                                                              |
# |2147609766|[storm]                                                                                                                  |
# |2147609785|[forecasting, power bi, excel, tableau, sql]                                                                             |
# |2147609929|[rest, excel]                                                                                                            |
# |2195921577|[forecasting, statistics, excel]                                                                                         |
# |2234533717|[agile, nodejs, react, ci/cd, postgresql, javascript, google cloud, aws, azure, mongodb, typescript, python]             |
# |2428973832|[excel]                                                                                                                  |
# |2748500131|[storm]                                                                                                                  |
# |3127577086|[excel]                                                                                                                  |
# |3196627399|[html, spring]                                                                                                           |
# |3245063922|[redshift, lambda, kinesis, data warehousing, glue, spark, aws, athena, s3, python, sql]                                 |
# |3297645846|[power bi, excel]                                                                                                        |
# |3299509053|[go]                                                                                                                     |
# |3366698309|[agile, statistics, excel, informatica, oracle]                                                                          |
# |3377655935|[excel]                                                                                                                  |
# |3383214611|[excel]                                                                                                                  |
# |3438976411|[excel]                                                                                                                  |
# |3447180215|[excel]                                                                                                                  |
# |3475933396|[agile, .net, c, sql server, javascript, scrum, html, c#, asp.net, sql]                                                  |
# |3480552482|[c]                                                                                                                      |
# |3487703305|[excel]                                                                                                                  |
# |3515274431|[excel]                                                                                                                  |
# |3547664337|[excel]                                                                                                                  |
# |3564676727|[forecasting]                                                                                                            |
# |3586167732|[rest, postgresql, javascript, typescript, go, gcp, kafka]                                                               |
# |3609090859|[excel]                                                                                                                  |
# |3625991523|[ci/cd, terraform, ansible, python, tls]                                                                                 |
# |3626110567|[statistics, excel]                                                                                                      |
# |3629278196|[shell]                                                                                                                  |
# |3639866700|[python]                                                                                                                 |
# |3662420217|[excel]                                                                                                                  |
# |3663813835|[excel]                                                                                                                  |
# |3681437990|[go]                                                                                                                     |
# |3700064749|[excel]                                                                                                                  |
# |3700068571|[agile, scrum, oracle]                                                                                                   |
# |3700617207|[excel]                                                                                                                  |
# |3700694895|[elt]                                                                                                                    |
# |3702659694|[ssl, shell, encryption, python]                                                                                         |
# |3710273988|[agile, encryption, aws, gcp]                                                                                            |
# |3726732147|[excel]                                                                                                                  |
# |3726764279|[excel]                                                                                                                  |
# |3727712512|[excel]                                                                                                                  |
# |3728459637|[sqs, nodejs, lambda, ci/cd, eks, aws, typescript]                                                                       |
# |3736994600|[go]                                                                                                                     |
# |3738844984|[forecasting, excel]                                                                                                     |
# |3742692445|[shell, snowflake, dimensional modeling, informatica, python, etl, sql, kafka]                                           |
# |3743875708|[react, javascript, github, express, html, css]                                                                          |
# |3747072157|[excel]                                                                                                                  |
# |3755323506|[excel]                                                                                                                  |
# |3769518300|[go]                                                                                                                     |
# |3773564741|[excel]                                                                                                                  |
# |3780415828|[sql server, sql]                                                                                                        |
# |3783977901|[sass]                                                                                                                   |
# |3784120102|[machine learning, artificial intelligence, nlp, python, neural networks]                                                |
# |3792953441|[react, excel, go]                                                                                                       |
# |3795156068|[iam, css]                                                                                                               |
# |3795156313|[excel]                                                                                                                  |
# |3800272386|[agile, pandas, aws, numpy, python, jira, ci/cd, kubernetes, snowflake, matplotlib, docker, git, plotly, azure, gcp, sql]|
# |3800989742|[mysql, apache, nodejs, lambda, react, javascript, docker, git, html, aws, typescript, css, php]                         |
# |3802602037|[unit testing, agile, c++, python, java]                                                                                 |
# |3803052628|[c++]                                                                                                                    |
# |3803659249|[agile, sql]                                                                                                             |
# |3808747564|[express, python, matlab]                                                                                                |
# |3813135937|[excel, go]                                                                                                              |
# |3815485980|[html, css]                                                                                                              |
# |3816179292|[excel]                                                                                                                  |
# |3816415678|[c]                                                                                                                      |
# |3816831972|[go]                                                                                                                     |
# |3817203807|[excel]                                                                                                                  |
# |3821047961|[go]                                                                                                                     |
# |3822435165|[llm]                                                                                                                    |
# |3827923756|[sql server, .net, c, c#, sql]                                                                                           |
# |3830297838|[express]                                                                                                                |
# |3830916199|[excel, go]                                                                                                              |
# |3832947295|[rest]                                                                                                                   |
# |3835703401|[excel]                                                                                                                  |
# |3837546918|[excel]                                                                                                                  |
# |3840217276|[athena]                                                                                                                 |
# |3840584142|[go]                                                                                                                     |
# |3840688146|[helm, excel]                                                                                                            |
# |3841963841|[react, javascript, git]                                                                                                 |
# |3842513172|[excel]                                                                                                                  |
# |3843043188|[oracle, sql]                                                                                                            |
# |3844025327|[excel]                                                                                                                  |
# |3844035605|[excel]                                                                                                                  |
# |3848960304|[pytorch, machine learning, python, deep learning]                                                                       |
# |3853719293|[go]                                                                                                                     |
# |3854137450|[excel]                                                                                                                  |
# |3857325080|[prometheus, excel]                                                                                                      |
# |3857348297|[agile]                                                                                                                  |
# |3857386463|[kafka, spring boot, spring, java]                                                                                       |
# |3859073094|[excel]                                                                                                                  |
# +----------+-------------------------------------------------------------------------------------------------------------------------+
# only showing top 100 rows
#
# +----------------+----------+---------+
# |skill_a         |skill_b   |job_count|
# +----------------+----------+---------+
# |python          |sql       |1845     |
# |agile           |scrum     |1337     |
# |aws             |python    |1310     |
# |aws             |azure     |1296     |
# |excel           |go        |1280     |
# |agile           |sql       |1220     |
# |forecasting     |excel     |1143     |
# |c               |c#        |1069     |
# |python          |java      |1046     |
# |agile           |python    |1022     |
# |agile           |java      |1017     |
# |agile           |aws       |999      |
# |azure           |sql       |997      |
# |excel           |sql       |959      |
# |agile           |azure     |957      |
# |aws             |sql       |914      |
# |sql server      |sql       |892      |
# |machine learning|python    |862      |
# |c               |python    |851      |
# |c               |sql       |829      |
# |javascript      |html      |815      |
# |oracle          |sql       |811      |
# |c               |c++       |808      |
# |sql             |java      |808      |
# |agile           |jira      |799      |
# |javascript      |sql       |784      |
# |agile           |javascript|752      |
# |aws             |java      |752      |
# |c++             |python    |709      |
# |agile           |excel     |669      |
# |c#              |sql       |665      |
# |agile           |go        |661      |
# |kubernetes      |docker    |651      |
# |tableau         |sql       |635      |
# |etl             |sql       |628      |
# |agile           |c         |626      |
# |javascript      |java      |616      |
# |azure           |python    |609      |
# |agile           |ci/cd     |590      |
# |excel           |oracle    |573      |
# |r               |python    |563      |
# |c               |javascript|562      |
# |agile           |git       |556      |
# |javascript      |python    |551      |
# |c               |go        |540      |
# |excel           |tableau   |534      |
# |html            |sql       |532      |
# |statistics      |python    |526      |
# |agile           |rest      |519      |
# |c               |excel     |515      |
# +----------------+----------+---------+
# only showing top 50 rows

# %%
top_pairs = (
    skill_bundle_counts
    .filter(F.col("job_count") >= 200) 
    .orderBy(F.desc("job_count"))
)

top_pairs.show(50, truncate=False)
# Out:
# +----------------+----------+---------+
# |skill_a         |skill_b   |job_count|
# +----------------+----------+---------+
# |python          |sql       |1845     |
# |agile           |scrum     |1337     |
# |aws             |python    |1310     |
# |aws             |azure     |1296     |
# |excel           |go        |1280     |
# |agile           |sql       |1220     |
# |forecasting     |excel     |1143     |
# |c               |c#        |1069     |
# |python          |java      |1046     |
# |agile           |python    |1022     |
# |agile           |java      |1017     |
# |agile           |aws       |999      |
# |azure           |sql       |997      |
# |excel           |sql       |959      |
# |agile           |azure     |957      |
# |aws             |sql       |914      |
# |sql server      |sql       |892      |
# |machine learning|python    |862      |
# |c               |python    |851      |
# |c               |sql       |829      |
# |javascript      |html      |815      |
# |oracle          |sql       |811      |
# |c               |c++       |808      |
# |sql             |java      |808      |
# |agile           |jira      |799      |
# |javascript      |sql       |784      |
# |agile           |javascript|752      |
# |aws             |java      |752      |
# |c++             |python    |709      |
# |agile           |excel     |669      |
# |c#              |sql       |665      |
# |agile           |go        |661      |
# |kubernetes      |docker    |651      |
# |tableau         |sql       |635      |
# |etl             |sql       |628      |
# |agile           |c         |626      |
# |javascript      |java      |616      |
# |azure           |python    |609      |
# |agile           |ci/cd     |590      |
# |excel           |oracle    |573      |
# |r               |python    |563      |
# |c               |javascript|562      |
# |agile           |git       |556      |
# |javascript      |python    |551      |
# |c               |go        |540      |
# |excel           |tableau   |534      |
# |html            |sql       |532      |
# |statistics      |python    |526      |
# |agile           |rest      |519      |
# |c               |excel     |515      |
# +----------------+----------+---------+
# only showing top 50 rows

# %%
job_salary = df_rows.select("job_id", "normalized_salary").filter(F.col("normalized_salary") > 0)

pair_salary = (
    skill_pairs
    .join(job_salary, on="job_id", how="inner")
    .groupBy("skill_a", "skill_b")
    .agg(
        F.countDistinct("job_id").alias("job_count"),
        F.avg("normalized_salary").alias("avg_salary")
    )
    .filter(F.col("job_count") >= 100)
    .orderBy(F.desc("avg_salary"))
)

pair_salary.show(50, truncate=False)
# Out:
# +----------------+-----------------------+---------+------------------+
# |skill_a         |skill_b                |job_count|avg_salary        |
# +----------------+-----------------------+---------+------------------+
# |javascript      |css                    |109      |942102.3331686746 |
# |html            |css                    |147      |828895.9891440502 |
# |aws             |azure                  |349      |821656.2467959304 |
# |javascript      |html                   |153      |616075.7445086705 |
# |machine learning|artificial intelligence|211      |177466.58050161813|
# |spark           |python                 |126      |163944.17513455328|
# |machine learning|aws                    |115      |163172.5682123656 |
# |c++             |python                 |192      |162428.76901408448|
# |machine learning|python                 |309      |162363.54731315628|
# |data pipelines  |python                 |100      |158983.5836637589 |
# |c               |aws                    |108      |156992.44397192405|
# |c++             |java                   |156      |156598.6124497992 |
# |aws             |go                     |141      |155425.40429404145|
# |go              |java                   |107      |155307.05539473685|
# |aws             |gcp                    |105      |154874.62191558443|
# |kubernetes      |docker                 |176      |153814.84466287214|
# |aws             |java                   |183      |153541.74345211583|
# |python          |java                   |292      |153414.0222827804 |
# |machine learning|statistics             |131      |152756.61444444445|
# |c               |c++                    |241      |151840.45770886727|
# |machine learning|sql                    |151      |151594.13738839285|
# |python          |etl                    |104      |151408.3675611681 |
# |aws             |python                 |350      |151401.79430629793|
# |ci/cd           |azure                  |119      |151383.58599392098|
# |aws             |sql                    |239      |149898.76555111556|
# |go              |python                 |156      |149043.66485955057|
# |kubernetes      |azure                  |123      |148487.02771752837|
# |go              |sql                    |145      |148399.7098782344 |
# |ci/cd           |docker                 |111      |148237.44956022946|
# |kubernetes      |aws                    |111      |147910.9997032641 |
# |c               |go                     |202      |147773.90475505442|
# |c               |excel                  |152      |147717.98715789473|
# |data modeling   |sql                    |138      |147673.99076330982|
# |c               |python                 |239      |147590.3949544271 |
# |docker          |azure                  |116      |147055.6187600744 |
# |ci/cd           |kubernetes             |113      |146984.96767824495|
# |agile           |ci/cd                  |155      |146799.92707240293|
# |agile           |kubernetes             |115      |145321.74747209455|
# |c#              |sql                    |122      |145258.307729805  |
# |agile           |react                  |115      |145096.69588414635|
# |azure           |python                 |158      |144915.1667085427 |
# |python          |sql                    |517      |144815.82803309182|
# |ci/cd           |aws                    |117      |144522.89166666666|
# |.net            |c#                     |114      |144504.567890625  |
# |c               |java                   |163      |144500.73520833332|
# |agile           |python                 |289      |144432.02082755632|
# |ci/cd           |python                 |100      |144286.65535889872|
# |agile           |aws                    |260      |144178.282526967  |
# |c               |azure                  |122      |143315.76886314267|
# |agile           |docker                 |111      |143027.2905940594 |
# +----------------+-----------------------+---------+------------------+
# only showing top 50 rows

# %%
top_pairs.write.mode("overwrite").parquet("data/skill_bundles_top.parquet")
pair_salary.write.mode("overwrite").parquet("data/skill_bundles_salary.parquet")
