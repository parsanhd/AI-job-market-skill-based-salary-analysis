# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Test').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Hersheyyyyy:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.parquet('cleaned_postings.parquet')
df_pyspark=spark.read.option('header','true').parquet('cleaned_postings.parquet',inferSchema=True)

# %%
type(df_pyspark)
df_pyspark.printSchema()
# Out:
# root
#  |-- job_id: long (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- skills_desc: string (nullable = true)
#  |-- normalized_salary: double (nullable = true)
#  |-- formatted_experience_level: string (nullable = true)
#  |-- formatted_work_type: string (nullable = true)
#  |-- remote_allowed: boolean (nullable = true)
#  |-- posting_domain: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- listed_time: double (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- extracted_skills: string (nullable = true)

# %%
from pyspark.sql import functions as F
df_rows = df_pyspark.withColumn("extracted_individual_skill", F.explode(F.split(F.col("extracted_skills"), "\|")))
df_rows.show(100)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\|'
# <>:2: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\harsh\AppData\Local\Temp\ipykernel_28872\1310979937.py:2: SyntaxWarning: invalid escape sequence '\|'
#   df_rows = df_pyspark.withColumn("extracted_individual_skill", F.explode(F.split(F.col("extracted_skills"), "\|")))
# +----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------------+--------------------+-----------+--------+--------------------+--------------------------+
# |    job_id|        company_name|               title|         description|         skills_desc|normalized_salary|formatted_experience_level|formatted_work_type|remote_allowed|      posting_domain|            location|listed_time|zip_code|    extracted_skills|extracted_individual_skill|
# +----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------------+--------------------+-----------+--------+--------------------+--------------------------+
# |    921716|Corcoran Sawyer S...|Marketing Coordin...|Job descriptionA ...|Requirements: \n\...|          38480.0|                      NULL|          Full-time|         false|                NULL|       Princeton, NJ|  1.7134E12|  8540.0|                    |                          |
# |   1829192|             Unknown|Mental Health The...|At Aspen Therapy ...|                    |          83200.0|                      NULL|          Full-time|         false|                NULL|    Fort Collins, CO| 1.71286E12|  8540.0|                    |                          |
# |  10998357|The National Exem...|Assitant Restaura...|The National Exem...|We are currently ...|          55000.0|                      NULL|          Full-time|         false|                NULL|      Cincinnati, OH| 1.71328E12|  8540.0|                    |                          |
# |  23221523|Abrams Fensterman...|Senior Elder Law ...|Senior Associate ...|This position req...|         157500.0|                      NULL|          Full-time|         false|                NULL|   New Hyde Park, NY|  1.7129E12|  8540.0|                    |                          |
# |  35982263|             Unknown|  Service Technician|Looking for HVAC ...|                    |          70000.0|                      NULL|          Full-time|         false|                NULL|      Burlington, IA| 1.71345E12|  8540.0|                    |                          |
# |  91700727|Downtown Raleigh ...|Economic Developm...|Job summary:The E...|                    |          35360.0|                      NULL|         Internship|         false|                NULL|         Raleigh, NC| 1.71346E12|  8540.0|                    |                          |
# | 103254301|          Raw Cereal|            Producer|Company Descripti...|                    |         180000.0|                      NULL|           Contract|          true|                NULL|       United States| 1.71286E12|  8540.0|                    |                          |
# | 112576855|             Unknown|   Building Engineer|Summary: Due to t...|                    |         105000.0|                      NULL|          Full-time|         false|                NULL|   San Francisco, CA| 1.71244E12|  8540.0|                    |                          |
# |   1218575| Children's Nebraska|Respiratory Thera...|At Children’s, th...|• Requires the ab...|              0.0|                      NULL|          Full-time|         false|                NULL|           Omaha, NE| 1.71235E12|  8540.0|                    |                          |
# |   2264355|     Bay West Church|      Worship Leader|It is an exciting...|Knowledge, Skills...|           4200.0|                      NULL|          Part-time|         false|                NULL|        Palm Bay, FL| 1.71246E12|  8540.0|                    |                          |
# |   9615617|    Glastender, Inc.|Inside Customer S...|Glastender Inc. i...|The Production Su...|              0.0|                      NULL|          Full-time|         false|                NULL|         Saginaw, MI| 1.71321E12|  8540.0|                    |                          |
# |  11009123|   PGAV Destinations|   Project Architect|PGAV Destinations...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        St Louis, MO| 1.71286E12|  8540.0|                    |                          |
# |  56482768|             Unknown|Appalachian Highl...|FULL JOB DESCRIPT...|Skills/Qualificat...|              0.0|                      NULL|          Full-time|         false|                NULL|       Kingsport, TN| 1.71287E12|  8540.0|               excel|                     excel|
# |  56924323|             Unknown| Structural Engineer|Universal Structu...|Job Overview: Man...|              0.0|                      NULL|          Full-time|         false|                NULL|       San Mateo, CA| 1.71246E12|  8540.0|               excel|                     excel|
# |  69333422|     Staffing Theory|Senior Product Ma...|A leading pharmac...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71354E12|  8540.0|                    |                          |
# |  83789755|         OsteoStrong|Osteogenic Loadin...|Company Descripti...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|       Anchorage, AK| 1.71347E12|  8540.0|                  go|                        go|
# |  95428182|CLEVELAND KIDS BO...|Administrative Co...|Job Title: Admini...|                    |          52000.0|                      NULL|          Full-time|         false|                NULL|       Cleveland, OH| 1.71286E12|  8540.0|                    |                          |
# | 103860943|             Unknown|Customer Service ...|Sentinel Limousin...|                    |          38480.0|                      NULL|          Part-time|         false|                NULL|      Providence, RI| 1.71353E12|  8540.0|                    |                          |
# | 111513530|United Methodists...|Content Writer, C...|Application openi...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|Greater Philadelphia| 1.71346E12|  8540.0|                    |                          |
# | 115639136|   Shannon Waltchack|          Controller|WORK @ SWShannon ...|Strong interperso...|              0.0|                      NULL|          Full-time|         false|                NULL|      Birmingham, AL| 1.71321E12|  8540.0|               excel|                     excel|
# | 117675818|Premier Family Cl...| Physician Assistant|We are seeking a ...|                    |              0.0|                      NULL|           Contract|         false|                NULL|         Atlanta, GA| 1.71267E12|  8540.0|                    |                          |
# | 121605673|             Unknown|Licensed Acupunct...|Why Work Here?“We...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|          Maumee, OH| 1.71347E12|  8540.0|                    |                          |
# | 133130219|             Unknown|   Software Engineer|Education Bachelo...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|Los Angeles Metro...| 1.71354E12|  8540.0|                    |                          |
# | 134286190|             Unknown|Sheet Metal Fabri...|Sheet metal fabri...|Data Entry Filing...|              0.0|                      NULL|          Full-time|         false|                NULL|   Mineral Wells, TX| 1.71346E12|  8540.0|               excel|                     excel|
# | 136743465|             Unknown|Personal Injury A...|About Us: We are ...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|          Stuart, FL| 1.71347E12|  8540.0|                  go|                        go|
# | 141969940|          PRM-TAIWAN|NPE 2024 Exhibiti...|NPE 2024 Exhibiti...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|         Orlando, FL| 1.71265E12|  8540.0|                    |                          |
# | 175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                       css|
# | 175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                      html|
# | 175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                javascript|
# | 175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                     mysql|
# | 175485704|                GOYT|   Software Engineer|Job Description:G...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|          Denver, CO| 1.71328E12|  8540.0|css|html|javascri...|                       php|
# | 196406165|             Unknown|    Loan Coordinator|Morlen Capital Ad...|                    |              0.0|                      NULL|           Contract|          true|                NULL|New Jersey, Unite...| 1.71353E12|  8540.0|               excel|                     excel|
# | 227832999|             Unknown|     General Laborer|Looking for a Gen...|                    |          43680.0|                      NULL|          Full-time|         false|                NULL|            Erie, PA| 1.71328E12|  8540.0|               excel|                     excel|
# | 228003844|Harlingen Country...|     Swim Instructor|HCC is looking to...|                    |              0.0|                      NULL|           Contract|         false|                NULL|       Harlingen, TX| 1.71339E12|  8540.0|                    |                          |
# | 229924287|REquipment Durabl...|Administrative As...|The Administrativ...|                    |          47840.0|                      NULL|          Part-time|         false|                NULL|          Woburn, MA| 1.71355E12|  8540.0|                    |                          |
# | 231010577|Pierce Refrigeration|Service / Constru...|Company Descripti...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|West Bridgewater, MA| 1.71246E12|  8540.0|                    |                          |
# | 243731357|Fidelity National...|     Legal Secretary|Description Legal...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|         Phoenix, AZ| 1.71244E12|  8540.0|                    |                          |
# | 258868844|                ABME|         Salesperson|ABME, a leader in...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71347E12|  8540.0|                    |                          |
# | 263583866|      Atrium Centers|    Registered Nurse|We currently need...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        Grayling, MI| 1.71347E12|  8540.0|                    |                          |
# | 266566927|  Revesco Properties|Marketing & Offic...|About Revesco Pro...|                    |          65000.0|                      NULL|          Full-time|         false|                NULL|          Denver, CO| 1.71346E12|  8540.0|               excel|                     excel|
# | 266825034|  Recruitment Design|Software Support ...|Are you driven by...|                    |          62500.0|                      NULL|          Full-time|         false|                NULL|          McLean, VA| 1.71286E12|  8540.0|      javascript|php|                javascript|
# | 266825034|  Recruitment Design|Software Support ...|Are you driven by...|                    |          62500.0|                      NULL|          Full-time|         false|                NULL|          McLean, VA| 1.71286E12|  8540.0|      javascript|php|                       php|
# | 280496925|Washington State ...|Coordinator for M...|The Coordinator s...|                    |          53268.0|                      NULL|          Full-time|         false|                NULL|         Pullman, WA| 1.71346E12|  8540.0|                    |                          |
# | 345332937|Headquarters Barb...|              Barber|Part time Barber,...|                    |              0.0|                      NULL|          Part-time|         false|                NULL|         Grafton, WI|  1.7134E12|  8540.0|                    |                          |
# | 358267047| ADEPT HRM Solutions|Production Planne...|Job Summary: We a...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|         Concord, NC| 1.71235E12|  8540.0|                    |                          |
# | 368586246|       STL Fertility|        Embryologist|Job duties:To rec...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        St Louis, MO| 1.71345E12|  8540.0|               excel|                     excel|
# | 445337908| Food Bank of Alaska|Chief Operating O...|The Chief Operati...|                    |         100000.0|                      NULL|          Full-time|         false|                NULL|       Anchorage, AK| 1.71355E12|  8540.0|                    |                          |
# | 606178500|Jung & Vassar PC ...|  Associate Attorney|Big Island firm s...|                    |         120000.0|                      NULL|          Full-time|         false|                NULL|     Kailua-Kona, HI| 1.71244E12|  8540.0|                    |                          |
# | 634823509|             Unknown|     HVAC Technician|Service and insta...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        Brooklyn, NY| 1.71349E12|  8540.0|                    |                          |
# | 658723396|Orlando Credit Union|External Mortgage...|Full job descript...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|         Orlando, FL| 1.71349E12|  8540.0|                    |                          |
# | 705356075|Blackland Home In...|TREC licensed Pro...|Candidate is requ...|                    |          54080.0|                      NULL|          Full-time|         false|                NULL|Dallas-Fort Worth...| 1.71347E12|  8540.0|                    |                          |
# | 805229245|             Unknown|Manager, Retail P...|SUMMARY:Manages o...|                    |         137500.0|                      NULL|          Full-time|         false|                NULL|          Tucson, AZ| 1.71321E12|  8540.0|                    |                          |
# | 844454682|             Unknown|Commercial Proper...|Gordon Partners (...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|         Houston, TX| 1.71321E12|  8540.0|               excel|                     excel|
# | 857299959|             Unknown|               SALES|Business Telecomm...|                    |          65000.0|                      NULL|          Full-time|         false|                NULL|      Hackensack, NJ| 1.71353E12|  8540.0|                    |                          |
# | 935210241|Einbinder & Dunn LLP|Transactional Att...|Growing, boutique...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        New York, NY| 1.71287E12|  8540.0|                    |                          |
# | 974774701|Kate Meadows Writ...|Blog writer and v...|Company Descripti...|                    |              0.0|                      NULL|           Contract|          true|                NULL|South Dakota, Uni...| 1.71235E12|  8540.0|                    |                          |
# |1014822088|             Tracker|Marketing Specialist|About TrackerTrac...|                    |          75000.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71347E12|  8540.0|                    |                          |
# |1093227543|               POSHI|Sales Associate N...|OVERVIEW:Poshi LL...|                    |          90000.0|                      NULL|          Full-time|         false|                NULL|           Miami, FL| 1.71339E12|  8540.0|                    |                          |
# |1129235875|TURNER HYDRAULICS...|Industrial Sales ...|&nbsp;Job descrip...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|       Lancaster, PA| 1.71321E12|  8540.0|                    |                          |
# |1143359956|             Unknown|National Sales Ma...|We are seeking a ...|                    |          80000.0|                      NULL|          Full-time|         false|                NULL|     Los Angeles, CA| 1.71321E12|  8540.0|         forecasting|               forecasting|
# |1168783207|             Unknown|        Reps manager|We are looking fo...|                    |              0.0|                      NULL|          Part-time|          true|                NULL|           Macon, GA| 1.71349E12|  8540.0|                    |                          |
# |1183148438|             Unknown|Montessori Lead G...|Montessori Primar...|                    |          61000.0|                      NULL|          Full-time|         false|                NULL|          Austin, TX| 1.71345E12|  8540.0|              athena|                    athena|
# |1219205895|             Unknown|Director of Training|Job Posting: Serv...|                    |         130000.0|                      NULL|          Full-time|         false|                NULL|        New York, NY| 1.71263E12|  8540.0|                    |                          |
# |1448163866|        Genlabs Corp|      Office Manager|Responsibilities:...|                    |          67500.0|                      NULL|          Full-time|         false|                NULL|           Chino, CA| 1.71244E12|  8540.0|               excel|                     excel|
# |1573178251|             Unknown|Social Media Coor...|🚀 Exciting Oppor...|                    |              0.0|                      NULL|          Part-time|          true|                NULL|New York, United ...| 1.71355E12|  8540.0|                    |                          |
# |1586552873|A.G.P./Alliance G...|Equity Institutio...|Role:Equity Capit...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|New York City Met...| 1.71286E12|  8540.0|                    |                          |
# |1755471110|          NeuroJust |Front Desk Admini...|NeuroJust and Bio...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|        Metairie, LA| 1.71355E12|  8540.0|                    |                          |
# |1826257634|  The Medicare Coach|Social Security S...|Do you have a bac...|                    |          45760.0|                      NULL|          Full-time|          true|                NULL|Colorado, United ...| 1.71321E12|  8540.0|            excel|go|                     excel|
# |1826257634|  The Medicare Coach|Social Security S...|Do you have a bac...|                    |          45760.0|                      NULL|          Full-time|          true|                NULL|Colorado, United ...| 1.71321E12|  8540.0|            excel|go|                        go|
# |1880409118|Kona Medical Cons...|Board Certified B...|JOB OVERVIEW:\nTh...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|       McDonough, GA| 1.71351E12|  8540.0|                    |                          |
# |2011147642|    BWE Home Theater|      Lead Installer|Position: Lead In...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|          Fresno, CA|  1.7134E12|  8540.0|                    |                          |
# |2147609712|     The Job Network|           Med-RN ER|Job Position: Reg...|                    |         117332.8|                      NULL|          Full-time|         false|arrowstaffingserv...|        Murrieta, CA|  1.7129E12|  8540.0|                    |                          |
# |2147609754|     The Job Network|Workflow Coordina...|Williams Lea is h...|                    |              0.0|                      NULL|          Full-time|         false|williamsleagroupl...|     San Antonio, TX|  1.7129E12|  8540.0|                    |                          |
# |2147609766|     The Job Network|Sales Representative|Hiring for May 20...|                    |         110000.0|                      NULL|          Full-time|         false|bartlettroofing.t...|           Ogden, UT|  1.7129E12|  8540.0|               storm|                     storm|
# |2147609774|     The Job Network|Dental Hygienist ...|Pay Range: $40-$7...|                    |              0.0|                      NULL|          Full-time|         false|tempmee.thejobnet...|      Huntington, NY|  1.7129E12|  8540.0|                    |                          |
# |2147609785|     The Job Network|        FP&A Analyst|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|          Dallas, TX|  1.7129E12|  8540.0|excel|forecasting...|                     excel|
# |2147609785|     The Job Network|        FP&A Analyst|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|          Dallas, TX|  1.7129E12|  8540.0|excel|forecasting...|               forecasting|
# |2147609785|     The Job Network|        FP&A Analyst|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|          Dallas, TX|  1.7129E12|  8540.0|excel|forecasting...|                  power bi|
# |2147609785|     The Job Network|        FP&A Analyst|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|          Dallas, TX|  1.7129E12|  8540.0|excel|forecasting...|                       sql|
# |2147609785|     The Job Network|        FP&A Analyst|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|          Dallas, TX|  1.7129E12|  8540.0|excel|forecasting...|                   tableau|
# |2147609789|            Revature|Entry Level Oracl...|About RevatureRev...|                    |              0.0|               Entry level|          Full-time|         false|                NULL|    East Chicago, IN|  1.7129E12|  8540.0|              oracle|                    oracle|
# |2147609816|     The Job Network|Maintenance Mechanic|We're growing! Ca...|                    |              0.0|                      NULL|          Full-time|         false|virginiaeconomicd...|         Suffolk, VA|  1.7129E12|  8540.0|                    |                          |
# |2147609835|     The Job Network|Trade Review Prin...|Integrity is one ...|                    |              0.0|                      NULL|          Full-time|         false|integritymarketin...|       Urbandale, IA|  1.7129E12|  8540.0|                    |                          |
# |2147609840|     The Job Network|Mover/Junk Hauler...|HIRING IMMEDIATEL...|                    |          46800.0|                      NULL|          Temporary|         false|chattr-transactio...|        St Louis, MO|  1.7129E12|  8540.0|                  go|                        go|
# |2147609858|     The Job Network|Dental CAD/CAM De...|Seeking an experi...|                    |              0.0|                      NULL|          Full-time|         false|directdental.thej...|         Memphis, TN|  1.7129E12|  8540.0|                   r|                         r|
# |2147609929|     The Job Network|  Production Planner|Location: Hanover...|                    |              0.0|                      NULL|          Full-time|         false|yohskf.thejobnetw...|         Hanover, PA|  1.7129E12|  8540.0|          excel|rest|                     excel|
# |2147609929|     The Job Network|  Production Planner|Location: Hanover...|                    |              0.0|                      NULL|          Full-time|         false|yohskf.thejobnetw...|         Hanover, PA|  1.7129E12|  8540.0|          excel|rest|                      rest|
# |2157930553|Brady Insurance G...|Customer Service ...|CUSTOMER SERVICE ...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|          Kokomo, IN| 1.71354E12|  8540.0|                    |                          |
# |2195921577|             Unknown|   Associate Planner|Reports To: Direc...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|            Waco, TX| 1.71339E12|  8540.0|excel|forecasting...|                     excel|
# |2195921577|             Unknown|   Associate Planner|Reports To: Direc...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|            Waco, TX| 1.71339E12|  8540.0|excel|forecasting...|               forecasting|
# |2195921577|             Unknown|   Associate Planner|Reports To: Direc...|                    |              0.0|                      NULL|          Full-time|         false|                NULL|            Waco, TX| 1.71339E12|  8540.0|excel|forecasting...|                statistics|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                     agile|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                       aws|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                     azure|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                     ci/cd|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|              google cloud|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                javascript|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                   mongodb|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                   node.js|
# |2234533717|         Ideando Inc| Full Stack Engineer|Location: Remote\...|                    |              0.0|                      NULL|          Full-time|          true|                NULL|       United States| 1.71349E12|  8540.0|agile|aws|azure|c...|                postgresql|
# +----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------------+-------------------+--------------+--------------------+--------------------+-----------+--------+--------------------+--------------------------+
# only showing top 100 rows

# %%
(
    df_rows
    .filter(F.col("extracted_individual_skill").isNotNull())
    .filter(F.trim(F.col("extracted_individual_skill")) != "")
    .groupBy("extracted_individual_skill")
    .count()
    .orderBy(F.desc("count"))
    .show(1000, truncate=False)
)
# Out:
# +------------------------------+-----+
# |extracted_individual_skill    |count|
# +------------------------------+-----+
# |excel                         |17851|
# |go                            |8762 |
# |agile                         |5932 |
# |c                             |5406 |
# |sql                           |5039 |
# |python                        |4536 |
# |aws                           |3034 |
# |forecasting                   |2956 |
# |azure                         |2825 |
# |rest                          |2712 |
# |java                          |2631 |
# |oracle                        |2301 |
# |statistics                    |1943 |
# |javascript                    |1904 |
# |express                       |1791 |
# |machine learning              |1704 |
# |scrum                         |1527 |
# |jira                          |1480 |
# |r                             |1479 |
# |react                         |1358 |
# |ci/cd                         |1325 |
# |html                          |1237 |
# |c++                           |1225 |
# |tableau                       |1214 |
# |spring                        |1143 |
# |git                           |1134 |
# |kubernetes                    |1091 |
# |c#                            |1074 |
# |docker                        |1032 |
# |artificial intelligence       |1030 |
# |power bi                      |988  |
# |gcp                           |928  |
# |css                           |920  |
# |sql server                    |897  |
# |etl                           |872  |
# |spark                         |837  |
# |.net                          |764  |
# |jenkins                       |728  |
# |powershell                    |678  |
# |angular                       |660  |
# |data modeling                 |646  |
# |shell                         |639  |
# |terraform                     |635  |
# |confluence                    |547  |
# |kafka                         |531  |
# |google cloud                  |522  |
# |snowflake                     |513  |
# |typescript                    |510  |
# |ansible                       |506  |
# |github                        |504  |
# |soap                          |485  |
# |unit testing                  |474  |
# |bash                          |450  |
# |data pipelines                |442  |
# |mysql                         |429  |
# |iam                           |426  |
# |azure devops                  |404  |
# |data warehousing              |399  |
# |splunk                        |384  |
# |scala                         |375  |
# |apache                        |365  |
# |s3                            |364  |
# |swift                         |363  |
# |lambda                        |348  |
# |spring boot                   |337  |
# |encryption                    |334  |
# |node.js                       |327  |
# |generative ai                 |322  |
# |postgresql                    |309  |
# |hadoop                        |307  |
# |matlab                        |303  |
# |storm                         |283  |
# |deep learning                 |282  |
# |mongodb                       |279  |
# |amazon web services           |278  |
# |gitlab                        |276  |
# |ruby                          |276  |
# |integration testing           |262  |
# |postgres                      |238  |
# |pytorch                       |236  |
# |delta                         |233  |
# |php                           |233  |
# |computer vision               |233  |
# |llm                           |230  |
# |selenium                      |227  |
# |rest api                      |225  |
# |tensorflow                    |221  |
# |helm                          |219  |
# |redshift                      |216  |
# |transformers                  |215  |
# |a/b testing                   |209  |
# |nlp                           |200  |
# |glue                          |197  |
# |data lake                     |194  |
# |informatica                   |193  |
# |nodejs                        |185  |
# |natural language processing   |184  |
# |golang                        |183  |
# |ssis                          |179  |
# |asp.net                       |177  |
# |ecs                           |176  |
# |redis                         |169  |
# |bitbucket                     |168  |
# |airflow                       |167  |
# |oauth                         |167  |
# |hive                          |166  |
# |dynamodb                      |161  |
# |data factory                  |158  |
# |elt                           |156  |
# |looker                        |154  |
# |dbt                           |153  |
# |grafana                       |148  |
# |graphql                       |143  |
# |clustering                    |142  |
# |ssl                           |140  |
# |pyspark                       |139  |
# |cassandra                     |139  |
# |bootstrap                     |134  |
# |kotlin                        |134  |
# |prometheus                    |132  |
# |cloudformation                |129  |
# |data pipeline                 |128  |
# |cypress                       |127  |
# |junit                         |126  |
# |datadog                       |125  |
# |adls                          |123  |
# |rust                          |122  |
# |elk                           |122  |
# |api gateway                   |116  |
# |eks                           |114  |
# |synapse                       |114  |
# |cloudwatch                    |108  |
# |genai                         |107  |
# |django                        |100  |
# |teradata                      |98   |
# |sqs                           |98   |
# |tls                           |97   |
# |bigquery                      |96   |
# |apache spark                  |95   |
# |mlops                         |94   |
# |pandas                        |93   |
# |vue                           |92   |
# |neural networks               |90   |
# |acr                           |89   |
# |elasticsearch                 |89   |
# |athena                        |83   |
# |time series                   |83   |
# |sns                           |82   |
# |numpy                         |81   |
# |scikit-learn                  |79   |
# |flask                         |74   |
# |gitlab ci                     |69   |
# |sass                          |68   |
# |github actions                |68   |
# |aks                           |64   |
# |rbac                          |63   |
# |azure functions               |59   |
# |cosmos db                     |57   |
# |talend                        |56   |
# |ecr                           |54   |
# |dataflow                      |54   |
# |flink                         |54   |
# |mssql                         |53   |
# |kinesis                       |51   |
# |jupyter                       |50   |
# |rabbitmq                      |49   |
# |gcs                           |47   |
# |nginx                         |47   |
# |lakehouse                     |45   |
# |new relic                     |41   |
# |delta lake                    |41   |
# |model deployment              |40   |
# |sagemaker                     |40   |
# |openai                        |39   |
# |keras                         |37   |
# |pub/sub                       |37   |
# |dimensional modeling          |36   |
# |grpc                          |35   |
# |presto                        |34   |
# |mariadb                       |34   |
# |hdfs                          |34   |
# |rag                           |33   |
# |neo4j                         |33   |
# |gke                           |32   |
# |matplotlib                    |32   |
# |spark streaming               |32   |
# |recommendation systems        |31   |
# |openid connect                |31   |
# |logistic regression           |31   |
# |mlflow                        |31   |
# |next.js                       |30   |
# |orc                           |30   |
# |asp.net core                  |29   |
# |langchain                     |29   |
# |circleci                      |28   |
# |prompt engineering            |27   |
# |stitch                        |27   |
# |nextjs                        |25   |
# |fastapi                       |25   |
# |opensearch                    |25   |
# |fargate                       |24   |
# |bigtable                      |24   |
# |jwt                           |23   |
# |linear regression             |23   |
# |parquet                       |23   |
# |pytest                        |22   |
# |large language model          |20   |
# |nltk                          |20   |
# |sqlite                        |20   |
# |kubeflow                      |19   |
# |recommender systems           |19   |
# |fivetran                      |19   |
# |yarn                          |18   |
# |oauth2                        |18   |
# |spacy                         |17   |
# |experiment design             |17   |
# |opencv                        |17   |
# |iceberg                       |17   |
# |plotly                        |16   |
# |scipy                         |16   |
# |tailwind                      |16   |
# |ci / cd                       |15   |
# |svm                           |15   |
# |k-means                       |14   |
# |embeddings                    |13   |
# |cloud run                     |12   |
# |star schema                   |12   |
# |cloud functions               |11   |
# |azure openai                  |11   |
# |trino                         |11   |
# |avro                          |11   |
# |random forest                 |11   |
# |model monitoring              |11   |
# |model serving                 |11   |
# |xgboost                       |10   |
# |vector database               |10   |
# |snowflake schema              |10   |
# |ab testing                    |8    |
# |hugging face                  |8    |
# |dagster                       |7    |
# |prefect                       |7    |
# |retrieval augmented generation|7    |
# |pubsub                        |6    |
# |feature store                 |6    |
# |chroma                        |6    |
# |sklearn                       |6    |
# |pinecone                      |6    |
# |jupyter notebook              |6    |
# |pulumi                        |5    |
# |llamaindex                    |5    |
# |superset                      |5    |
# |c #                           |4    |
# |onnx                          |3    |
# |vector db                     |3    |
# |faiss                         |3    |
# |naive bayes                   |3    |
# |e2e testing                   |2    |
# |luigi                         |2    |
# |metabase                      |2    |
# |unittest                      |2    |
# |milvus                        |2    |
# |lightgbm                      |1    |
# |weaviate                      |1    |
# |statsmodels                   |1    |
# +------------------------------+-----+

# %%
skill_map = {
    "node.js": "nodejs",
    "ci / cd": "ci/cd",
    "amazon web services": "aws",
    "natural language processing": "nlp",
    "golang": "go",
    "postgres": "postgresql",
    "c #": "c#",
    "apache spark": "spark",
    "ab testing": "a/b testing"
    #add more if needed
}
mapping_expr = F.create_map(
    *[F.lit(x) for pair in skill_map.items() for x in pair]
)

df_norm = df_rows.withColumn(
    "skill",
    F.coalesce(mapping_expr[F.col("extracted_individual_skill")], F.col("extracted_individual_skill"))
)

# %%
(
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .dropDuplicates(["job_id", "skill"])
    .groupBy("skill")
    .count()
    .orderBy(F.desc("count"))
    .show(1000, truncate=False)
)
# Out:
# +------------------------------+-----+
# |skill                         |count|
# +------------------------------+-----+
# |excel                         |17851|
# |go                            |8893 |
# |agile                         |5932 |
# |c                             |5406 |
# |sql                           |5039 |
# |python                        |4536 |
# |aws                           |3118 |
# |forecasting                   |2956 |
# |azure                         |2825 |
# |rest                          |2712 |
# |java                          |2631 |
# |oracle                        |2301 |
# |statistics                    |1943 |
# |javascript                    |1904 |
# |express                       |1791 |
# |machine learning              |1704 |
# |scrum                         |1527 |
# |jira                          |1480 |
# |r                             |1479 |
# |react                         |1358 |
# |ci/cd                         |1339 |
# |html                          |1237 |
# |c++                           |1225 |
# |tableau                       |1214 |
# |spring                        |1143 |
# |git                           |1134 |
# |kubernetes                    |1091 |
# |c#                            |1077 |
# |docker                        |1032 |
# |artificial intelligence       |1030 |
# |power bi                      |988  |
# |gcp                           |928  |
# |css                           |920  |
# |sql server                    |897  |
# |etl                           |872  |
# |spark                         |837  |
# |.net                          |764  |
# |jenkins                       |728  |
# |powershell                    |678  |
# |angular                       |660  |
# |data modeling                 |646  |
# |shell                         |639  |
# |terraform                     |635  |
# |confluence                    |547  |
# |kafka                         |531  |
# |postgresql                    |523  |
# |google cloud                  |522  |
# |snowflake                     |513  |
# |typescript                    |510  |
# |ansible                       |506  |
# |github                        |504  |
# |nodejs                        |489  |
# |soap                          |485  |
# |unit testing                  |474  |
# |bash                          |450  |
# |data pipelines                |442  |
# |mysql                         |429  |
# |iam                           |426  |
# |azure devops                  |404  |
# |data warehousing              |399  |
# |splunk                        |384  |
# |scala                         |375  |
# |apache                        |365  |
# |s3                            |364  |
# |swift                         |363  |
# |lambda                        |348  |
# |spring boot                   |337  |
# |encryption                    |334  |
# |generative ai                 |322  |
# |nlp                           |313  |
# |hadoop                        |307  |
# |matlab                        |303  |
# |storm                         |283  |
# |deep learning                 |282  |
# |mongodb                       |279  |
# |gitlab                        |276  |
# |ruby                          |276  |
# |integration testing           |262  |
# |pytorch                       |236  |
# |delta                         |233  |
# |php                           |233  |
# |computer vision               |233  |
# |llm                           |230  |
# |selenium                      |227  |
# |rest api                      |225  |
# |tensorflow                    |221  |
# |helm                          |219  |
# |a/b testing                   |216  |
# |redshift                      |216  |
# |transformers                  |215  |
# |glue                          |197  |
# |data lake                     |194  |
# |informatica                   |193  |
# |ssis                          |179  |
# |asp.net                       |177  |
# |ecs                           |176  |
# |redis                         |169  |
# |bitbucket                     |168  |
# |airflow                       |167  |
# |oauth                         |167  |
# |hive                          |166  |
# |dynamodb                      |161  |
# |data factory                  |158  |
# |elt                           |156  |
# |looker                        |154  |
# |dbt                           |153  |
# |grafana                       |148  |
# |graphql                       |143  |
# |clustering                    |142  |
# |ssl                           |140  |
# |pyspark                       |139  |
# |cassandra                     |139  |
# |bootstrap                     |134  |
# |kotlin                        |134  |
# |prometheus                    |132  |
# |cloudformation                |129  |
# |data pipeline                 |128  |
# |cypress                       |127  |
# |junit                         |126  |
# |datadog                       |125  |
# |adls                          |123  |
# |rust                          |122  |
# |elk                           |122  |
# |api gateway                   |116  |
# |eks                           |114  |
# |synapse                       |114  |
# |cloudwatch                    |108  |
# |genai                         |107  |
# |django                        |100  |
# |teradata                      |98   |
# |sqs                           |98   |
# |tls                           |97   |
# |bigquery                      |96   |
# |mlops                         |94   |
# |pandas                        |93   |
# |vue                           |92   |
# |neural networks               |90   |
# |acr                           |89   |
# |elasticsearch                 |89   |
# |athena                        |83   |
# |time series                   |83   |
# |sns                           |82   |
# |numpy                         |81   |
# |scikit-learn                  |79   |
# |flask                         |74   |
# |gitlab ci                     |69   |
# |sass                          |68   |
# |github actions                |68   |
# |aks                           |64   |
# |rbac                          |63   |
# |azure functions               |59   |
# |cosmos db                     |57   |
# |talend                        |56   |
# |ecr                           |54   |
# |dataflow                      |54   |
# |flink                         |54   |
# |mssql                         |53   |
# |kinesis                       |51   |
# |jupyter                       |50   |
# |rabbitmq                      |49   |
# |gcs                           |47   |
# |nginx                         |47   |
# |lakehouse                     |45   |
# |new relic                     |41   |
# |delta lake                    |41   |
# |model deployment              |40   |
# |sagemaker                     |40   |
# |openai                        |39   |
# |keras                         |37   |
# |pub/sub                       |37   |
# |dimensional modeling          |36   |
# |grpc                          |35   |
# |presto                        |34   |
# |mariadb                       |34   |
# |hdfs                          |34   |
# |rag                           |33   |
# |neo4j                         |33   |
# |gke                           |32   |
# |matplotlib                    |32   |
# |spark streaming               |32   |
# |recommendation systems        |31   |
# |openid connect                |31   |
# |logistic regression           |31   |
# |mlflow                        |31   |
# |next.js                       |30   |
# |orc                           |30   |
# |asp.net core                  |29   |
# |langchain                     |29   |
# |circleci                      |28   |
# |prompt engineering            |27   |
# |stitch                        |27   |
# |nextjs                        |25   |
# |fastapi                       |25   |
# |opensearch                    |25   |
# |fargate                       |24   |
# |bigtable                      |24   |
# |jwt                           |23   |
# |linear regression             |23   |
# |parquet                       |23   |
# |pytest                        |22   |
# |large language model          |20   |
# |nltk                          |20   |
# |sqlite                        |20   |
# |kubeflow                      |19   |
# |recommender systems           |19   |
# |fivetran                      |19   |
# |yarn                          |18   |
# |oauth2                        |18   |
# |spacy                         |17   |
# |experiment design             |17   |
# |opencv                        |17   |
# |iceberg                       |17   |
# |plotly                        |16   |
# |scipy                         |16   |
# |tailwind                      |16   |
# |svm                           |15   |
# |k-means                       |14   |
# |embeddings                    |13   |
# |cloud run                     |12   |
# |star schema                   |12   |
# |cloud functions               |11   |
# |azure openai                  |11   |
# |trino                         |11   |
# |avro                          |11   |
# |random forest                 |11   |
# |model monitoring              |11   |
# |model serving                 |11   |
# |xgboost                       |10   |
# |vector database               |10   |
# |snowflake schema              |10   |
# |hugging face                  |8    |
# |dagster                       |7    |
# |prefect                       |7    |
# |retrieval augmented generation|7    |
# |pubsub                        |6    |
# |feature store                 |6    |
# |chroma                        |6    |
# |sklearn                       |6    |
# |pinecone                      |6    |
# |jupyter notebook              |6    |
# |pulumi                        |5    |
# |llamaindex                    |5    |
# |superset                      |5    |
# |onnx                          |3    |
# |vector db                     |3    |
# |faiss                         |3    |
# |naive bayes                   |3    |
# |e2e testing                   |2    |
# |luigi                         |2    |
# |metabase                      |2    |
# |unittest                      |2    |
# |milvus                        |2    |
# |lightgbm                      |1    |
# |weaviate                      |1    |
# |statsmodels                   |1    |
# +------------------------------+-----+

# %%
skills_by_level = (
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .fillna({"formatted_experience_level": "Unknown"})
    .groupBy("formatted_experience_level", "skill")
    .agg(F.countDistinct("job_id").alias("job_count"))
    .orderBy("formatted_experience_level", F.desc("job_count"))
)

skills_by_level.show(1000, truncate=False)
# Out:
# +--------------------------+------------------------------+---------+
# |formatted_experience_level|skill                         |job_count|
# +--------------------------+------------------------------+---------+
# |Associate                 |excel                         |1961     |
# |Associate                 |go                            |614      |
# |Associate                 |agile                         |429      |
# |Associate                 |sql                           |351      |
# |Associate                 |c                             |303      |
# |Associate                 |python                        |267      |
# |Associate                 |forecasting                   |244      |
# |Associate                 |statistics                    |181      |
# |Associate                 |oracle                        |158      |
# |Associate                 |azure                         |148      |
# |Associate                 |aws                           |127      |
# |Associate                 |r                             |124      |
# |Associate                 |jira                          |122      |
# |Associate                 |rest                          |121      |
# |Associate                 |java                          |117      |
# |Associate                 |tableau                       |103      |
# |Associate                 |spring                        |98       |
# |Associate                 |machine learning              |95       |
# |Associate                 |express                       |92       |
# |Associate                 |react                         |81       |
# |Associate                 |power bi                      |78       |
# |Associate                 |javascript                    |73       |
# |Associate                 |scrum                         |70       |
# |Associate                 |c++                           |68       |
# |Associate                 |html                          |64       |
# |Associate                 |css                           |61       |
# |Associate                 |powershell                    |54       |
# |Associate                 |spark                         |54       |
# |Associate                 |git                           |50       |
# |Associate                 |etl                           |49       |
# |Associate                 |gcp                           |49       |
# |Associate                 |sql server                    |47       |
# |Associate                 |artificial intelligence       |46       |
# |Associate                 |ci/cd                         |42       |
# |Associate                 |c#                            |40       |
# |Associate                 |shell                         |39       |
# |Associate                 |swift                         |38       |
# |Associate                 |kubernetes                    |38       |
# |Associate                 |docker                        |36       |
# |Associate                 |confluence                    |33       |
# |Associate                 |postgresql                    |28       |
# |Associate                 |terraform                     |28       |
# |Associate                 |github                        |28       |
# |Associate                 |typescript                    |28       |
# |Associate                 |snowflake                     |26       |
# |Associate                 |kafka                         |26       |
# |Associate                 |data modeling                 |26       |
# |Associate                 |.net                          |25       |
# |Associate                 |encryption                    |25       |
# |Associate                 |angular                       |24       |
# |Associate                 |data warehousing              |24       |
# |Associate                 |unit testing                  |23       |
# |Associate                 |data pipelines                |23       |
# |Associate                 |mysql                         |22       |
# |Associate                 |ansible                       |22       |
# |Associate                 |gitlab                        |21       |
# |Associate                 |bash                          |21       |
# |Associate                 |llm                           |20       |
# |Associate                 |google cloud                  |20       |
# |Associate                 |soap                          |19       |
# |Associate                 |jenkins                       |18       |
# |Associate                 |storm                         |17       |
# |Associate                 |prometheus                    |17       |
# |Associate                 |matlab                        |17       |
# |Associate                 |delta                         |17       |
# |Associate                 |nodejs                        |16       |
# |Associate                 |mongodb                       |15       |
# |Associate                 |ruby                          |15       |
# |Associate                 |apache                        |15       |
# |Associate                 |a/b testing                   |15       |
# |Associate                 |azure devops                  |15       |
# |Associate                 |integration testing           |15       |
# |Associate                 |lambda                        |15       |
# |Associate                 |iam                           |14       |
# |Associate                 |rust                          |14       |
# |Associate                 |looker                        |13       |
# |Associate                 |generative ai                 |12       |
# |Associate                 |ssl                           |12       |
# |Associate                 |data pipeline                 |12       |
# |Associate                 |scala                         |12       |
# |Associate                 |tls                           |11       |
# |Associate                 |ecs                           |11       |
# |Associate                 |ssis                          |11       |
# |Associate                 |rest api                      |11       |
# |Associate                 |transformers                  |10       |
# |Associate                 |spring boot                   |10       |
# |Associate                 |clustering                    |10       |
# |Associate                 |splunk                        |10       |
# |Associate                 |deep learning                 |10       |
# |Associate                 |informatica                   |10       |
# |Associate                 |time series                   |10       |
# |Associate                 |grafana                       |10       |
# |Associate                 |graphql                       |9        |
# |Associate                 |hadoop                        |9        |
# |Associate                 |s3                            |9        |
# |Associate                 |redis                         |8        |
# |Associate                 |selenium                      |8        |
# |Associate                 |datadog                       |8        |
# |Associate                 |sass                          |8        |
# |Associate                 |elt                           |8        |
# |Associate                 |gitlab ci                     |8        |
# |Associate                 |data lake                     |8        |
# |Associate                 |glue                          |8        |
# |Associate                 |helm                          |8        |
# |Associate                 |cassandra                     |8        |
# |Associate                 |elk                           |7        |
# |Associate                 |airflow                       |7        |
# |Associate                 |bitbucket                     |7        |
# |Associate                 |kotlin                        |7        |
# |Associate                 |hive                          |7        |
# |Associate                 |php                           |7        |
# |Associate                 |nlp                           |7        |
# |Associate                 |pandas                        |7        |
# |Associate                 |sqs                           |6        |
# |Associate                 |acr                           |6        |
# |Associate                 |bigquery                      |6        |
# |Associate                 |teradata                      |5        |
# |Associate                 |elasticsearch                 |5        |
# |Associate                 |vue                           |5        |
# |Associate                 |cloudformation                |5        |
# |Associate                 |cypress                       |5        |
# |Associate                 |cloudwatch                    |5        |
# |Associate                 |orc                           |5        |
# |Associate                 |computer vision               |5        |
# |Associate                 |dynamodb                      |5        |
# |Associate                 |bootstrap                     |4        |
# |Associate                 |redshift                      |4        |
# |Associate                 |azure functions               |4        |
# |Associate                 |numpy                         |4        |
# |Associate                 |pytorch                       |4        |
# |Associate                 |pyspark                       |4        |
# |Associate                 |oauth                         |4        |
# |Associate                 |tensorflow                    |4        |
# |Associate                 |junit                         |4        |
# |Associate                 |athena                        |4        |
# |Associate                 |circleci                      |3        |
# |Associate                 |large language model          |3        |
# |Associate                 |scikit-learn                  |3        |
# |Associate                 |ecr                           |3        |
# |Associate                 |talend                        |3        |
# |Associate                 |github actions                |3        |
# |Associate                 |mssql                         |3        |
# |Associate                 |grpc                          |3        |
# |Associate                 |neural networks               |3        |
# |Associate                 |data factory                  |2        |
# |Associate                 |avro                          |2        |
# |Associate                 |opencv                        |2        |
# |Associate                 |nginx                         |2        |
# |Associate                 |flink                         |2        |
# |Associate                 |synapse                       |2        |
# |Associate                 |api gateway                   |2        |
# |Associate                 |keras                         |2        |
# |Associate                 |aks                           |2        |
# |Associate                 |rabbitmq                      |2        |
# |Associate                 |prefect                       |2        |
# |Associate                 |fargate                       |2        |
# |Associate                 |stitch                        |2        |
# |Associate                 |presto                        |2        |
# |Associate                 |mariadb                       |1        |
# |Associate                 |openai                        |1        |
# |Associate                 |adls                          |1        |
# |Associate                 |new relic                     |1        |
# |Associate                 |parquet                       |1        |
# |Associate                 |tailwind                      |1        |
# |Associate                 |pytest                        |1        |
# |Associate                 |xgboost                       |1        |
# |Associate                 |django                        |1        |
# |Associate                 |svm                           |1        |
# |Associate                 |openid connect                |1        |
# |Associate                 |gcs                           |1        |
# |Associate                 |eks                           |1        |
# |Associate                 |mlops                         |1        |
# |Associate                 |gke                           |1        |
# |Associate                 |flask                         |1        |
# |Associate                 |sns                           |1        |
# |Associate                 |next.js                       |1        |
# |Associate                 |sqlite                        |1        |
# |Associate                 |star schema                   |1        |
# |Associate                 |recommender systems           |1        |
# |Associate                 |cloud run                     |1        |
# |Associate                 |logistic regression           |1        |
# |Associate                 |opensearch                    |1        |
# |Associate                 |model deployment              |1        |
# |Associate                 |dbt                           |1        |
# |Associate                 |linear regression             |1        |
# |Associate                 |rbac                          |1        |
# |Associate                 |trino                         |1        |
# |Associate                 |dimensional modeling          |1        |
# |Associate                 |recommendation systems        |1        |
# |Associate                 |pulumi                        |1        |
# |Associate                 |yarn                          |1        |
# |Associate                 |asp.net                       |1        |
# |Associate                 |cosmos db                     |1        |
# |Director                  |excel                         |581      |
# |Director                  |go                            |337      |
# |Director                  |forecasting                   |299      |
# |Director                  |agile                         |266      |
# |Director                  |c                             |195      |
# |Director                  |sql                           |97       |
# |Director                  |azure                         |90       |
# |Director                  |statistics                    |87       |
# |Director                  |python                        |84       |
# |Director                  |aws                           |83       |
# |Director                  |r                             |62       |
# |Director                  |tableau                       |59       |
# |Director                  |oracle                        |58       |
# |Director                  |gcp                           |58       |
# |Director                  |machine learning              |57       |
# |Director                  |scrum                         |55       |
# |Director                  |artificial intelligence       |51       |
# |Director                  |rest                          |50       |
# |Director                  |jira                          |47       |
# |Director                  |express                       |44       |
# |Director                  |spark                         |36       |
# |Director                  |java                          |35       |
# |Director                  |react                         |33       |
# |Director                  |data modeling                 |29       |
# |Director                  |power bi                      |27       |
# |Director                  |ci/cd                         |25       |
# |Director                  |generative ai                 |25       |
# |Director                  |splunk                        |22       |
# |Director                  |kubernetes                    |21       |
# |Director                  |etl                           |20       |
# |Director                  |snowflake                     |18       |
# |Director                  |spring                        |18       |
# |Director                  |data warehousing              |18       |
# |Director                  |apache                        |18       |
# |Director                  |ruby                          |18       |
# |Director                  |prometheus                    |17       |
# |Director                  |c#                            |17       |
# |Director                  |kafka                         |17       |
# |Director                  |google cloud                  |16       |
# |Director                  |encryption                    |15       |
# |Director                  |data pipelines                |14       |
# |Director                  |a/b testing                   |14       |
# |Director                  |sql server                    |14       |
# |Director                  |datadog                       |13       |
# |Director                  |looker                        |13       |
# |Director                  |javascript                    |13       |
# |Director                  |ansible                       |13       |
# |Director                  |informatica                   |12       |
# |Director                  |terraform                     |12       |
# |Director                  |elt                           |11       |
# |Director                  |delta                         |11       |
# |Director                  |helm                          |10       |
# |Director                  |mongodb                       |10       |
# |Director                  |.net                          |10       |
# |Director                  |confluence                    |10       |
# |Director                  |grafana                       |10       |
# |Director                  |docker                        |9        |
# |Director                  |deep learning                 |9        |
# |Director                  |hadoop                        |9        |
# |Director                  |llm                           |9        |
# |Director                  |c++                           |9        |
# |Director                  |azure devops                  |9        |
# |Director                  |genai                         |9        |
# |Director                  |unit testing                  |9        |
# |Director                  |github                        |8        |
# |Director                  |jenkins                       |8        |
# |Director                  |bash                          |8        |
# |Director                  |nlp                           |8        |
# |Director                  |html                          |8        |
# |Director                  |integration testing           |7        |
# |Director                  |storm                         |7        |
# |Director                  |data factory                  |7        |
# |Director                  |swift                         |7        |
# |Director                  |spring boot                   |7        |
# |Director                  |git                           |7        |
# |Director                  |mlops                         |7        |
# |Director                  |lakehouse                     |6        |
# |Director                  |computer vision               |6        |
# |Director                  |redshift                      |6        |
# |Director                  |postgresql                    |6        |
# |Director                  |s3                            |6        |
# |Director                  |delta lake                    |6        |
# |Director                  |data lake                     |6        |
# |Director                  |iam                           |6        |
# |Director                  |pytorch                       |6        |
# |Director                  |css                           |6        |
# |Director                  |shell                         |6        |
# |Director                  |mlflow                        |5        |
# |Director                  |elk                           |5        |
# |Director                  |tensorflow                    |5        |
# |Director                  |mysql                         |5        |
# |Director                  |php                           |5        |
# |Director                  |typescript                    |5        |
# |Director                  |dbt                           |4        |
# |Director                  |angular                       |4        |
# |Director                  |neural networks               |4        |
# |Director                  |cypress                       |4        |
# |Director                  |time series                   |4        |
# |Director                  |gitlab                        |4        |
# |Director                  |synapse                       |4        |
# |Director                  |glue                          |4        |
# |Director                  |lambda                        |3        |
# |Director                  |gcs                           |3        |
# |Director                  |pyspark                       |3        |
# |Director                  |graphql                       |3        |
# |Director                  |rag                           |3        |
# |Director                  |soap                          |3        |
# |Director                  |kinesis                       |3        |
# |Director                  |hive                          |3        |
# |Director                  |asp.net                       |3        |
# |Director                  |transformers                  |3        |
# |Director                  |oauth                         |3        |
# |Director                  |bigquery                      |3        |
# |Director                  |openai                        |3        |
# |Director                  |stitch                        |3        |
# |Director                  |kubeflow                      |2        |
# |Director                  |selenium                      |2        |
# |Director                  |presto                        |2        |
# |Director                  |tls                           |2        |
# |Director                  |matlab                        |2        |
# |Director                  |pub/sub                       |2        |
# |Director                  |iceberg                       |2        |
# |Director                  |teradata                      |2        |
# |Director                  |vue                           |2        |
# |Director                  |nodejs                        |2        |
# |Director                  |openid connect                |2        |
# |Director                  |flink                         |2        |
# |Director                  |ecs                           |2        |
# |Director                  |clustering                    |2        |
# |Director                  |spark streaming               |2        |
# |Director                  |aks                           |2        |
# |Director                  |cassandra                     |2        |
# |Director                  |django                        |2        |
# |Director                  |scala                         |2        |
# |Director                  |talend                        |2        |
# |Director                  |dynamodb                      |2        |
# |Director                  |bitbucket                     |2        |
# |Director                  |keras                         |2        |
# |Director                  |powershell                    |2        |
# |Director                  |jupyter                       |2        |
# |Director                  |svm                           |1        |
# |Director                  |oauth2                        |1        |
# |Director                  |flask                         |1        |
# |Director                  |mssql                         |1        |
# |Director                  |airflow                       |1        |
# |Director                  |rabbitmq                      |1        |
# |Director                  |feature store                 |1        |
# |Director                  |experiment design             |1        |
# |Director                  |onnx                          |1        |
# |Director                  |random forest                 |1        |
# |Director                  |model monitoring              |1        |
# |Director                  |langchain                     |1        |
# |Director                  |sklearn                       |1        |
# |Director                  |cosmos db                     |1        |
# |Director                  |hugging face                  |1        |
# |Director                  |cloudformation                |1        |
# |Director                  |recommender systems           |1        |
# |Director                  |prompt engineering            |1        |
# |Director                  |ssis                          |1        |
# |Director                  |circleci                      |1        |
# |Director                  |linear regression             |1        |
# |Director                  |acr                           |1        |
# |Director                  |azure functions               |1        |
# |Director                  |logistic regression           |1        |
# |Director                  |pandas                        |1        |
# |Director                  |rust                          |1        |
# |Director                  |api gateway                   |1        |
# |Director                  |model serving                 |1        |
# |Director                  |eks                           |1        |
# |Director                  |dataflow                      |1        |
# |Director                  |nextjs                        |1        |
# |Entry level               |excel                         |4663     |
# |Entry level               |go                            |2820     |
# |Entry level               |c                             |1196     |
# |Entry level               |agile                         |787      |
# |Entry level               |rest                          |768      |
# |Entry level               |python                        |663      |
# |Entry level               |sql                           |635      |
# |Entry level               |express                       |605      |
# |Entry level               |statistics                    |438      |
# |Entry level               |aws                           |405      |
# |Entry level               |java                          |383      |
# |Entry level               |oracle                        |382      |
# |Entry level               |azure                         |349      |
# |Entry level               |r                             |330      |
# |Entry level               |forecasting                   |306      |
# |Entry level               |machine learning              |276      |
# |Entry level               |javascript                    |261      |
# |Entry level               |react                         |212      |
# |Entry level               |c++                           |198      |
# |Entry level               |spring                        |197      |
# |Entry level               |html                          |196      |
# |Entry level               |jira                          |195      |
# |Entry level               |artificial intelligence       |173      |
# |Entry level               |git                           |169      |
# |Entry level               |scrum                         |162      |
# |Entry level               |css                           |160      |
# |Entry level               |ci/cd                         |160      |
# |Entry level               |c#                            |146      |
# |Entry level               |sql server                    |143      |
# |Entry level               |soap                          |140      |
# |Entry level               |tableau                       |137      |
# |Entry level               |kubernetes                    |131      |
# |Entry level               |docker                        |127      |
# |Entry level               |power bi                      |125      |
# |Entry level               |spark                         |118      |
# |Entry level               |shell                         |111      |
# |Entry level               |.net                          |110      |
# |Entry level               |powershell                    |107      |
# |Entry level               |gcp                           |102      |
# |Entry level               |swift                         |100      |
# |Entry level               |jenkins                       |99       |
# |Entry level               |etl                           |95       |
# |Entry level               |ansible                       |89       |
# |Entry level               |terraform                     |86       |
# |Entry level               |confluence                    |84       |
# |Entry level               |bash                          |81       |
# |Entry level               |storm                         |80       |
# |Entry level               |angular                       |80       |
# |Entry level               |transformers                  |80       |
# |Entry level               |matlab                        |77       |
# |Entry level               |mysql                         |75       |
# |Entry level               |unit testing                  |73       |
# |Entry level               |postgresql                    |72       |
# |Entry level               |data modeling                 |69       |
# |Entry level               |adls                          |67       |
# |Entry level               |github                        |65       |
# |Entry level               |typescript                    |63       |
# |Entry level               |s3                            |62       |
# |Entry level               |splunk                        |61       |
# |Entry level               |delta                         |61       |
# |Entry level               |kafka                         |59       |
# |Entry level               |data pipelines                |56       |
# |Entry level               |snowflake                     |54       |
# |Entry level               |iam                           |53       |
# |Entry level               |gitlab                        |52       |
# |Entry level               |computer vision               |51       |
# |Entry level               |nodejs                        |50       |
# |Entry level               |php                           |49       |
# |Entry level               |lambda                        |49       |
# |Entry level               |glue                          |49       |
# |Entry level               |azure devops                  |46       |
# |Entry level               |data warehousing              |45       |
# |Entry level               |encryption                    |45       |
# |Entry level               |hadoop                        |44       |
# |Entry level               |ruby                          |40       |
# |Entry level               |nlp                           |40       |
# |Entry level               |scala                         |40       |
# |Entry level               |apache                        |40       |
# |Entry level               |google cloud                  |39       |
# |Entry level               |rust                          |37       |
# |Entry level               |integration testing           |37       |
# |Entry level               |redshift                      |36       |
# |Entry level               |selenium                      |35       |
# |Entry level               |acr                           |34       |
# |Entry level               |asp.net                       |34       |
# |Entry level               |rest api                      |33       |
# |Entry level               |spring boot                   |32       |
# |Entry level               |generative ai                 |31       |
# |Entry level               |deep learning                 |30       |
# |Entry level               |dbt                           |30       |
# |Entry level               |bootstrap                     |29       |
# |Entry level               |mongodb                       |27       |
# |Entry level               |clustering                    |27       |
# |Entry level               |data lake                     |26       |
# |Entry level               |helm                          |26       |
# |Entry level               |cypress                       |25       |
# |Entry level               |ssis                          |25       |
# |Entry level               |bitbucket                     |23       |
# |Entry level               |airflow                       |23       |
# |Entry level               |ecs                           |22       |
# |Entry level               |hive                          |21       |
# |Entry level               |pytorch                       |20       |
# |Entry level               |junit                         |20       |
# |Entry level               |pyspark                       |20       |
# |Entry level               |kotlin                        |19       |
# |Entry level               |dynamodb                      |19       |
# |Entry level               |cloudformation                |19       |
# |Entry level               |tensorflow                    |18       |
# |Entry level               |ssl                           |18       |
# |Entry level               |sass                          |18       |
# |Entry level               |a/b testing                   |18       |
# |Entry level               |django                        |18       |
# |Entry level               |pandas                        |17       |
# |Entry level               |elk                           |17       |
# |Entry level               |informatica                   |17       |
# |Entry level               |looker                        |17       |
# |Entry level               |numpy                         |17       |
# |Entry level               |sqs                           |17       |
# |Entry level               |redis                         |16       |
# |Entry level               |sns                           |15       |
# |Entry level               |data pipeline                 |15       |
# |Entry level               |cassandra                     |15       |
# |Entry level               |cloudwatch                    |14       |
# |Entry level               |api gateway                   |14       |
# |Entry level               |data factory                  |14       |
# |Entry level               |elasticsearch                 |14       |
# |Entry level               |datadog                       |14       |
# |Entry level               |athena                        |14       |
# |Entry level               |orc                           |13       |
# |Entry level               |flask                         |13       |
# |Entry level               |graphql                       |13       |
# |Entry level               |prometheus                    |13       |
# |Entry level               |llm                           |13       |
# |Entry level               |elt                           |13       |
# |Entry level               |oauth                         |13       |
# |Entry level               |grafana                       |12       |
# |Entry level               |bigquery                      |12       |
# |Entry level               |aks                           |12       |
# |Entry level               |mariadb                       |11       |
# |Entry level               |logistic regression           |11       |
# |Entry level               |eks                           |11       |
# |Entry level               |mssql                         |11       |
# |Entry level               |synapse                       |10       |
# |Entry level               |nginx                         |10       |
# |Entry level               |tls                           |9        |
# |Entry level               |linear regression             |9        |
# |Entry level               |neural networks               |9        |
# |Entry level               |jupyter                       |9        |
# |Entry level               |kinesis                       |8        |
# |Entry level               |new relic                     |8        |
# |Entry level               |dimensional modeling          |7        |
# |Entry level               |talend                        |7        |
# |Entry level               |gitlab ci                     |7        |
# |Entry level               |matplotlib                    |7        |
# |Entry level               |k-means                       |7        |
# |Entry level               |vue                           |7        |
# |Entry level               |openai                        |6        |
# |Entry level               |yarn                          |6        |
# |Entry level               |circleci                      |6        |
# |Entry level               |gcs                           |6        |
# |Entry level               |azure functions               |6        |
# |Entry level               |rbac                          |6        |
# |Entry level               |time series                   |6        |
# |Entry level               |scikit-learn                  |6        |
# |Entry level               |opensearch                    |5        |
# |Entry level               |rabbitmq                      |5        |
# |Entry level               |teradata                      |5        |
# |Entry level               |next.js                       |5        |
# |Entry level               |keras                         |5        |
# |Entry level               |hdfs                          |5        |
# |Entry level               |delta lake                    |5        |
# |Entry level               |parquet                       |5        |
# |Entry level               |flink                         |5        |
# |Entry level               |asp.net core                  |4        |
# |Entry level               |mlops                         |4        |
# |Entry level               |pytest                        |4        |
# |Entry level               |prompt engineering            |4        |
# |Entry level               |rag                           |4        |
# |Entry level               |iceberg                       |4        |
# |Entry level               |neo4j                         |4        |
# |Entry level               |github actions                |4        |
# |Entry level               |pub/sub                       |3        |
# |Entry level               |model serving                 |3        |
# |Entry level               |avro                          |3        |
# |Entry level               |ecr                           |3        |
# |Entry level               |langchain                     |3        |
# |Entry level               |fastapi                       |3        |
# |Entry level               |retrieval augmented generation|3        |
# |Entry level               |cosmos db                     |3        |
# |Entry level               |model deployment              |3        |
# |Entry level               |scipy                         |3        |
# |Entry level               |genai                         |3        |
# |Entry level               |presto                        |3        |
# |Entry level               |large language model          |3        |
# |Entry level               |lakehouse                     |3        |
# |Entry level               |fivetran                      |3        |
# |Entry level               |stitch                        |3        |
# |Entry level               |spacy                         |2        |
# |Entry level               |opencv                        |2        |
# |Entry level               |trino                         |2        |
# |Entry level               |grpc                          |2        |
# |Entry level               |xgboost                       |2        |
# |Entry level               |nextjs                        |2        |
# |Entry level               |experiment design             |2        |
# |Entry level               |jwt                           |2        |
# |Entry level               |openid connect                |2        |
# |Entry level               |prefect                       |2        |
# |Entry level               |nltk                          |2        |
# |Entry level               |superset                      |2        |
# |Entry level               |tailwind                      |2        |
# |Entry level               |gke                           |2        |
# |Entry level               |azure openai                  |2        |
# |Entry level               |recommendation systems        |1        |
# |Entry level               |metabase                      |1        |
# |Entry level               |pulumi                        |1        |
# |Entry level               |onnx                          |1        |
# |Entry level               |llamaindex                    |1        |
# |Entry level               |kubeflow                      |1        |
# |Entry level               |e2e testing                   |1        |
# |Entry level               |plotly                        |1        |
# |Entry level               |hugging face                  |1        |
# |Entry level               |sqlite                        |1        |
# |Entry level               |vector database               |1        |
# |Entry level               |sklearn                       |1        |
# |Entry level               |fargate                       |1        |
# |Entry level               |snowflake schema              |1        |
# |Entry level               |star schema                   |1        |
# |Entry level               |random forest                 |1        |
# |Entry level               |sagemaker                     |1        |
# |Entry level               |embeddings                    |1        |
# |Entry level               |dataflow                      |1        |
# |Executive                 |excel                         |165      |
# |Executive                 |forecasting                   |143      |
# |Executive                 |go                            |86       |
# |Executive                 |c                             |76       |
# |Executive                 |agile                         |59       |
# |Executive                 |rest                          |34       |
# |Executive                 |machine learning              |27       |
# |Executive                 |aws                           |25       |
# |Executive                 |python                        |24       |
# |Executive                 |artificial intelligence       |23       |
# |Executive                 |express                       |20       |
# |Executive                 |r                             |17       |
# |Executive                 |react                         |16       |
# |Executive                 |azure                         |16       |
# |Executive                 |java                          |16       |
# |Executive                 |scrum                         |15       |
# |Executive                 |statistics                    |11       |
# |Executive                 |sql                           |11       |
# |Executive                 |oracle                        |11       |
# |Executive                 |nlp                           |11       |
# |Executive                 |generative ai                 |11       |
# |Executive                 |jira                          |10       |
# |Executive                 |spark                         |10       |
# |Executive                 |ci/cd                         |10       |
# |Executive                 |elt                           |9        |
# |Executive                 |spring                        |7        |
# |Executive                 |tableau                       |7        |
# |Executive                 |c#                            |7        |
# |Executive                 |deep learning                 |6        |
# |Executive                 |powershell                    |5        |
# |Executive                 |angular                       |5        |
# |Executive                 |kubernetes                    |5        |
# |Executive                 |confluence                    |5        |
# |Executive                 |gcp                           |5        |
# |Executive                 |.net                          |5        |
# |Executive                 |computer vision               |5        |
# |Executive                 |power bi                      |4        |
# |Executive                 |spring boot                   |4        |
# |Executive                 |kafka                         |4        |
# |Executive                 |helm                          |4        |
# |Executive                 |swift                         |4        |
# |Executive                 |genai                         |4        |
# |Executive                 |google cloud                  |4        |
# |Executive                 |snowflake                     |4        |
# |Executive                 |html                          |4        |
# |Executive                 |etl                           |4        |
# |Executive                 |terraform                     |4        |
# |Executive                 |javascript                    |4        |
# |Executive                 |ansible                       |3        |
# |Executive                 |postgresql                    |3        |
# |Executive                 |jenkins                       |3        |
# |Executive                 |nodejs                        |3        |
# |Executive                 |data modeling                 |3        |
# |Executive                 |sql server                    |3        |
# |Executive                 |docker                        |3        |
# |Executive                 |bitbucket                     |3        |
# |Executive                 |azure devops                  |3        |
# |Executive                 |c++                           |3        |
# |Executive                 |rest api                      |3        |
# |Executive                 |mongodb                       |3        |
# |Executive                 |data pipelines                |3        |
# |Executive                 |typescript                    |3        |
# |Executive                 |sass                          |2        |
# |Executive                 |github                        |2        |
# |Executive                 |git                           |2        |
# |Executive                 |iam                           |2        |
# |Executive                 |shell                         |2        |
# |Executive                 |gitlab                        |2        |
# |Executive                 |tensorflow                    |2        |
# |Executive                 |s3                            |2        |
# |Executive                 |looker                        |2        |
# |Executive                 |redshift                      |2        |
# |Executive                 |graphql                       |2        |
# |Executive                 |lambda                        |2        |
# |Executive                 |llm                           |2        |
# |Executive                 |encryption                    |2        |
# |Executive                 |vue                           |2        |
# |Executive                 |ecr                           |2        |
# |Executive                 |ruby                          |2        |
# |Executive                 |pytorch                       |2        |
# |Executive                 |ssl                           |1        |
# |Executive                 |unit testing                  |1        |
# |Executive                 |hadoop                        |1        |
# |Executive                 |data lake                     |1        |
# |Executive                 |prompt engineering            |1        |
# |Executive                 |mlflow                        |1        |
# |Executive                 |asp.net                       |1        |
# ...
# |Internship                |elt                           |1        |
# |Internship                |snowflake                     |1        |
# |Internship                |postgresql                    |1        |
# |Internship                |ecr                           |1        |
# |Internship                |pandas                        |1        |
# |Internship                |nltk                          |1        |
# |Internship                |new relic                     |1        |
# |Internship                |lambda                        |1        |
# |Internship                |synapse                       |1        |
# |Internship                |kubernetes                    |1        |
# |Internship                |ansible                       |1        |
# |Internship                |opencv                        |1        |
# |Internship                |dynamodb                      |1        |
# |Internship                |stitch                        |1        |
# |Internship                |angular                       |1        |
# |Internship                |experiment design             |1        |
# |Internship                |vector database               |1        |
# |Internship                |cypress                       |1        |
# |Internship                |kotlin                        |1        |
# |Internship                |linear regression             |1        |
# |Internship                |scikit-learn                  |1        |
# |Internship                |data warehousing              |1        |
# |Internship                |eks                           |1        |
# |Internship                |sqs                           |1        |
# |Internship                |recommendation systems        |1        |
# |Internship                |selenium                      |1        |
# |Internship                |splunk                        |1        |
# |Internship                |large language model          |1        |
# |Internship                |rust                          |1        |
# |Internship                |php                           |1        |
# |Internship                |docker                        |1        |
# |Internship                |jupyter notebook              |1        |
# |Internship                |terraform                     |1        |
# |Internship                |pinecone                      |1        |
# |Internship                |unit testing                  |1        |
# |Internship                |data pipelines                |1        |
# |Internship                |sns                           |1        |
# |Mid-Senior level          |excel                         |6536     |
# |Mid-Senior level          |agile                         |2967     |
# |Mid-Senior level          |go                            |2941     |
# |Mid-Senior level          |sql                           |2465     |
# |Mid-Senior level          |c                             |2394     |
# |Mid-Senior level          |python                        |2032     |
# |Mid-Senior level          |aws                           |1665     |
# |Mid-Senior level          |azure                         |1516     |
# |Mid-Senior level          |forecasting                   |1348     |
# |Mid-Senior level          |java                          |1260     |
# |Mid-Senior level          |oracle                        |1131     |
# |Mid-Senior level          |rest                          |1066     |
# |Mid-Senior level          |javascript                    |824      |
# |Mid-Senior level          |scrum                         |822      |
# |Mid-Senior level          |statistics                    |768      |
# |Mid-Senior level          |jira                          |756      |
# |Mid-Senior level          |machine learning              |737      |
# |Mid-Senior level          |ci/cd                         |680      |
# |Mid-Senior level          |tableau                       |633      |
# |Mid-Senior level          |kubernetes                    |622      |
# |Mid-Senior level          |r                             |609      |
# |Mid-Senior level          |docker                        |589      |
# |Mid-Senior level          |react                         |588      |
# |Mid-Senior level          |git                           |530      |
# |Mid-Senior level          |gcp                           |490      |
# |Mid-Senior level          |power bi                      |478      |
# |Mid-Senior level          |html                          |472      |
# |Mid-Senior level          |express                       |460      |
# |Mid-Senior level          |etl                           |452      |
# |Mid-Senior level          |c++                           |447      |
# |Mid-Senior level          |sql server                    |445      |
# |Mid-Senior level          |css                           |428      |
# |Mid-Senior level          |c#                            |423      |
# |Mid-Senior level          |spring                        |403      |
# |Mid-Senior level          |spark                         |401      |
# |Mid-Senior level          |.net                          |398      |
# |Mid-Senior level          |artificial intelligence       |388      |
# |Mid-Senior level          |powershell                    |366      |
# |Mid-Senior level          |terraform                     |351      |
# |Mid-Senior level          |jenkins                       |347      |
# |Mid-Senior level          |angular                       |333      |
# |Mid-Senior level          |data modeling                 |332      |
# |Mid-Senior level          |google cloud                  |306      |
# |Mid-Senior level          |confluence                    |294      |
# |Mid-Senior level          |shell                         |285      |
# |Mid-Senior level          |typescript                    |281      |
# |Mid-Senior level          |snowflake                     |279      |
# |Mid-Senior level          |nodejs                        |273      |
# |Mid-Senior level          |ansible                       |273      |
# |Mid-Senior level          |kafka                         |263      |
# |Mid-Senior level          |postgresql                    |256      |
# |Mid-Senior level          |github                        |254      |
# |Mid-Senior level          |scala                         |251      |
# |Mid-Senior level          |unit testing                  |241      |
# |Mid-Senior level          |data pipelines                |240      |
# |Mid-Senior level          |azure devops                  |234      |
# |Mid-Senior level          |bash                          |225      |
# |Mid-Senior level          |iam                           |224      |
# |Mid-Senior level          |mysql                         |216      |
# |Mid-Senior level          |data warehousing              |212      |
# |Mid-Senior level          |soap                          |194      |
# |Mid-Senior level          |splunk                        |194      |
# |Mid-Senior level          |apache                        |185      |
# |Mid-Senior level          |lambda                        |180      |
# |Mid-Senior level          |s3                            |179      |
# |Mid-Senior level          |encryption                    |175      |
# |Mid-Senior level          |hadoop                        |162      |
# |Mid-Senior level          |generative ai                 |155      |
# |Mid-Senior level          |spring boot                   |154      |
# |Mid-Senior level          |mongodb                       |149      |
# |Mid-Senior level          |ruby                          |136      |
# |Mid-Senior level          |helm                          |134      |
# |Mid-Senior level          |gitlab                        |134      |
# |Mid-Senior level          |nlp                           |125      |
# |Mid-Senior level          |llm                           |122      |
# |Mid-Senior level          |redshift                      |122      |
# |Mid-Senior level          |matlab                        |122      |
# |Mid-Senior level          |deep learning                 |116      |
# |Mid-Senior level          |swift                         |116      |
# |Mid-Senior level          |integration testing           |113      |
# |Mid-Senior level          |tensorflow                    |112      |
# |Mid-Senior level          |storm                         |111      |
# |Mid-Senior level          |pytorch                       |111      |
# |Mid-Senior level          |ecs                           |106      |
# |Mid-Senior level          |informatica                   |103      |
# |Mid-Senior level          |selenium                      |102      |
# |Mid-Senior level          |rest api                      |100      |
# |Mid-Senior level          |a/b testing                   |98       |
# |Mid-Senior level          |data factory                  |98       |
# |Mid-Senior level          |delta                         |98       |
# |Mid-Senior level          |data lake                     |96       |
# |Mid-Senior level          |computer vision               |95       |
# |Mid-Senior level          |ssis                          |93       |
# |Mid-Senior level          |asp.net                       |90       |
# |Mid-Senior level          |redis                         |90       |
# |Mid-Senior level          |php                           |89       |
# |Mid-Senior level          |airflow                       |89       |
# |Mid-Senior level          |glue                          |89       |
# |Mid-Senior level          |bitbucket                     |88       |
# |Mid-Senior level          |dynamodb                      |86       |
# |Mid-Senior level          |oauth                         |84       |
# |Mid-Senior level          |looker                        |81       |
# |Mid-Senior level          |hive                          |80       |
# |Mid-Senior level          |elt                           |80       |
# |Mid-Senior level          |grafana                       |77       |
# |Mid-Senior level          |data pipeline                 |76       |
# |Mid-Senior level          |clustering                    |76       |
# |Mid-Senior level          |transformers                  |73       |
# |Mid-Senior level          |ssl                           |70       |
# |Mid-Senior level          |dbt                           |70       |
# |Mid-Senior level          |cloudformation                |70       |
# |Mid-Senior level          |pyspark                       |69       |
# |Mid-Senior level          |graphql                       |69       |
# |Mid-Senior level          |bootstrap                     |66       |
# |Mid-Senior level          |kotlin                        |66       |
# |Mid-Senior level          |cassandra                     |66       |
# |Mid-Senior level          |synapse                       |64       |
# |Mid-Senior level          |eks                           |62       |
# |Mid-Senior level          |api gateway                   |62       |
# |Mid-Senior level          |prometheus                    |61       |
# |Mid-Senior level          |teradata                      |61       |
# |Mid-Senior level          |datadog                       |61       |
# |Mid-Senior level          |cypress                       |60       |
# |Mid-Senior level          |junit                         |60       |
# |Mid-Senior level          |elk                           |59       |
# |Mid-Senior level          |genai                         |56       |
# |Mid-Senior level          |cloudwatch                    |54       |
# |Mid-Senior level          |mlops                         |51       |
# |Mid-Senior level          |bigquery                      |46       |
# |Mid-Senior level          |elasticsearch                 |45       |
# |Mid-Senior level          |tls                           |43       |
# |Mid-Senior level          |neural networks               |43       |
# |Mid-Senior level          |scikit-learn                  |42       |
# |Mid-Senior level          |sqs                           |42       |
# |Mid-Senior level          |pandas                        |41       |
# |Mid-Senior level          |rbac                          |41       |
# |Mid-Senior level          |django                        |40       |
# |Mid-Senior level          |sns                           |40       |
# |Mid-Senior level          |vue                           |40       |
# |Mid-Senior level          |athena                        |40       |
# |Mid-Senior level          |acr                           |39       |
# |Mid-Senior level          |github actions                |39       |
# |Mid-Senior level          |rust                          |39       |
# |Mid-Senior level          |gitlab ci                     |39       |
# |Mid-Senior level          |time series                   |37       |
# |Mid-Senior level          |cosmos db                     |36       |
# |Mid-Senior level          |numpy                         |34       |
# |Mid-Senior level          |aks                           |34       |
# |Mid-Senior level          |dataflow                      |33       |
# |Mid-Senior level          |azure functions               |33       |
# |Mid-Senior level          |flink                         |32       |
# |Mid-Senior level          |talend                        |30       |
# |Mid-Senior level          |ecr                           |30       |
# |Mid-Senior level          |lakehouse                     |30       |
# |Mid-Senior level          |adls                          |29       |
# |Mid-Senior level          |flask                         |29       |
# |Mid-Senior level          |rabbitmq                      |29       |
# |Mid-Senior level          |sass                          |27       |
# |Mid-Senior level          |gcs                           |26       |
# |Mid-Senior level          |mssql                         |26       |
# |Mid-Senior level          |spark streaming               |25       |
# |Mid-Senior level          |grpc                          |25       |
# |Mid-Senior level          |sagemaker                     |25       |
# |Mid-Senior level          |model deployment              |25       |
# |Mid-Senior level          |bigtable                      |23       |
# |Mid-Senior level          |nginx                         |23       |
# |Mid-Senior level          |delta lake                    |22       |
# |Mid-Senior level          |kinesis                       |22       |
# |Mid-Senior level          |neo4j                         |21       |
# |Mid-Senior level          |mariadb                       |20       |
# |Mid-Senior level          |dimensional modeling          |20       |
# |Mid-Senior level          |asp.net core                  |20       |
# |Mid-Senior level          |openai                        |20       |
# |Mid-Senior level          |recommendation systems        |20       |
# |Mid-Senior level          |jupyter                       |20       |
# |Mid-Senior level          |mlflow                        |19       |
# |Mid-Senior level          |keras                         |18       |
# |Mid-Senior level          |presto                        |18       |
# |Mid-Senior level          |new relic                     |17       |
# |Mid-Senior level          |openid connect                |16       |
# |Mid-Senior level          |gke                           |15       |
# |Mid-Senior level          |pub/sub                       |15       |
# |Mid-Senior level          |fargate                       |15       |
# |Mid-Senior level          |hdfs                          |14       |
# |Mid-Senior level          |fivetran                      |14       |
# |Mid-Senior level          |jwt                           |14       |
# |Mid-Senior level          |rag                           |14       |
# |Mid-Senior level          |fastapi                       |14       |
# |Mid-Senior level          |logistic regression           |13       |
# |Mid-Senior level          |next.js                       |13       |
# +--------------------------+------------------------------+---------+
# only showing top 1000 rows

# %%
from pyspark.sql.functions import expr
job_skills = (
    df_norm
    .filter(F.col("skill").isNotNull())
    .filter(F.trim(F.col("skill")) != "")
    .groupBy("job_id")
    .agg(F.collect_set("skill").alias("skills"))
)
skill_pairs = (
    job_skills
    .withColumn(
        "skill_pairs",
        expr("""
            transform(
                filter(
                    sequence(0, size(skills) - 1),
                    i -> i < size(skills) - 1
                ),
                i -> transform(
                    sequence(i + 1, size(skills) - 1),
                    j -> struct(
                        skills[i] as skill_a,
                        skills[j] as skill_b
                    )
                )
            )
        """)
    )
    .select("job_id", F.explode("skill_pairs").alias("pairs"))
    .select("job_id", F.explode("pairs").alias("pair"))
    .select("job_id","pair.skill_a", "pair.skill_b")
)
skill_bundle_counts = (
    skill_pairs
    .groupBy("skill_a", "skill_b")
    .agg(F.countDistinct("job_id").alias("job_count"))
    .orderBy(F.desc("job_count"))
)
skill_bundle_counts.show(1000, truncate=False)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[28], line 36
#       2 job_skills = (
#       3     df_norm
#       4     .filter(F.col("skill").isNotNull())
#    (...)      7     .agg(F.collect_set("skill").alias("skills"))
#       8 )
#       9 skill_pairs = (
#      10     job_skills
#      11     .withColumn(
#    (...)     31     .select("pair.skill_a", "pair.skill_b")
#      32 )
#      33 skill_bundle_counts = (
#      34     skill_pairs
#      35     .groupBy("skill_a", "skill_b")
# ---> 36     .agg(F.countDistinct("job_id").alias("job_count"))
#      37     .orderBy(F.desc("job_count"))
#      38 )
#      39 skill_bundle_counts.show(1000, truncate=False)
#
# File c:\Users\harsh\OneDrive\Documents\AI job market\.venv\Lib\site-packages\pyspark\sql\group.py:186, in GroupedData.agg(self, *exprs)
#     184     assert all(isinstance(c, Column) for c in exprs), "all exprs should be Column"
#     185     exprs = cast(Tuple[Column, ...], exprs)
# --> 186     jdf = self._jgd.agg(exprs[0]._jc, _to_seq(self.session._sc, [c._jc for c in exprs[1:]]))
#     187 return DataFrame(jdf, self.session)
#
# File c:\Users\harsh\OneDrive\Documents\AI job market\.venv\Lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File c:\Users\harsh\OneDrive\Documents\AI job market\.venv\Lib\site-packages\pyspark\errors\exceptions\captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `job_id` cannot be resolved. Did you mean one of the following? [`skill_a`, `skill_b`].;
# 'Aggregate [skill_a#971, skill_b#972], [skill_a#971, skill_b#972, 'count(distinct 'job_id) AS job_count#977]
# +- Project [pair#968.skill_a AS skill_a#971, pair#968.skill_b AS skill_b#972]
#    +- Project [job_id#28L, pair#968]
#       +- Generate explode(pairs#964), false, [pair#968]
#          +- Project [job_id#28L, pairs#964]
#             +- Generate explode(skill_pairs#956), false, [pairs#964]
#                +- Project [job_id#28L, skills#951, transform(filter(sequence(0, (size(skills#951, true) - 1), None, Some(America/New_York)), lambdafunction((lambda i#957 < (size(skills#951, true) - 1)), lambda i#957, false)), lambdafunction(transform(sequence((lambda i#958 + 1), (size(skills#951, true) - 1), None, Some(America/New_York)), lambdafunction(struct(skill_a, skills#951[lambda i#958], skill_b, skills#951[lambda j#959]), lambda j#959, false)), lambda i#958, false)) AS skill_pairs#956]
#                   +- Aggregate [job_id#28L], [job_id#28L, collect_set(skill#154, 0, 0) AS skills#951]
#                      +- Filter NOT (trim(skill#154, None) = )
#                         +- Filter isnotnull(skill#154)
#                            +- Project [job_id#28L, company_name#29, title#30, description#31, skills_desc#32, normalized_salary#33, formatted_experience_level#34, formatted_work_type#35, remote_allowed#36, posting_domain#37, location#38, listed_time#39, zip_code#40, extracted_skills#41, extracted_individual_skill#57, coalesce(map(node.js, nodejs, ci / cd, ci/cd, amazon web services, aws, natural language processing, nlp, golang, go, postgres, postgresql, c #, c#, apache spark, spark, ab testing, a/b testing)[extracted_individual_skill#57], extracted_individual_skill#57) AS skill#154]
#                               +- Project [job_id#28L, company_name#29, title#30, description#31, skills_desc#32, normalized_salary#33, formatted_experience_level#34, formatted_work_type#35, remote_allowed#36, posting_domain#37, location#38, listed_time#39, zip_code#40, extracted_skills#41, extracted_individual_skill#57]
#                                  +- Generate explode(split(extracted_skills#41, \|, -1)), false, [extracted_individual_skill#57]
#                                     +- Relation [job_id#28L,company_name#29,title#30,description#31,skills_desc#32,normalized_salary#33,formatted_experience_level#34,formatted_work_type#35,remote_allowed#36,posting_domain#37,location#38,listed_time#39,zip_code#40,extracted_skills#41] parquet
